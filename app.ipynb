# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * 필요한 라이브러리 설치

# %%
# !pip install -q langchain-openai langchain-community streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 102.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.1 which is incompatible.

# %% [markdown]
# * 라이브러리 로딩

# %%
# 기본 제공 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import json
import os
import openai
import ast
import re

from typing import TypedDict, Annotated, List, Optional, Literal, Dict, Any
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langgraph.graph import END, START, StateGraph, MessagesState
from langchain_openai import ChatOpenAI

# 더 필요한 라이브러리가 있다면 추가합시다. -----
# Out:
# /usr/local/lib/python3.12/dist-packages/langgraph/cache/base/__init__.py:8: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %% [markdown]
# ### (3) OpenAI API Key 확인

# %%
def load_api_keys(filepath="api_key.txt"):
    with open(filepath, "r") as f:
        for line in f:
            line = line.strip()
            if line and "=" in line:
                key, value = line.split("=", 1)
                os.environ[key.strip()] = value.strip()

path = '/content/drive/MyDrive/proj2_agent/'

# API 키 로드 및 환경변수 설정
load_api_keys(path + 'api_key.txt')

# %%
print(os.environ['OPENAI_API_KEY'][:30])

# %% [markdown]
# * 운영환경 설정

# %%
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "proj2_agent"
os.environ["LANGSMITH_ENDPOINT"] = "https://api.smith.langchain.com"

# %% [markdown]
# #### **1) State & LLM 준비**

# %%
class ReviewState(TypedDict):
    messages: Annotated[list, add_messages]
    input_review: str
    score: int
    aspect_list: List[str]
    criti_score: str
    result: dict

    feedback: str

    next_step: Optional[Literal["analyzer", "critic", "end"]]
    max_num: int
    current_num: int

    current_agent: Optional[str]

# %% [markdown]
# * llm 준비

# %%
visor_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
analyzer_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
criti_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)

# %% [markdown]
# * Analyzer Agent

# %%
state: ReviewState = {
    "input_review": '보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.',
    "score": 3,
    "result": "",
    "aspect_list": ['보습', '가격', '향', '포장']
}

# %%
def analyzer_node(state: ReviewState):
  review = state.get("input_review") or []
  result = state.get("result") or []
  aspect_list = state.get("aspect_list") or []
  score = state.get("score") or 0
  feedback = state.get("criti_score") or "없음 (최초 분석)"

  sys = """
너는 리뷰 분석 전문가야. 다음 지침에 따라 입력받은 사용자의 리뷰를 분석해줘.
만약 [수정 요청 피드백]이 제공된다면, 이전의 실수를 교정하여 결과를 다시 작성해야 해.

[지침]
1. 제시된 [후보 속성] 중에서 리뷰에 언급된 것만 추출해.
2. **중요: 'aspect' 리스트에 담긴 속성의 순서는 반드시 [후보 속성]에 나열된 순서를 유지해야 해.**
3. 각 속성에 대한 만족도를 판별해 (만족/긍정은 1, 불만족/부정은 0).
4. 'label' 리스트의 값은 'aspect' 리스트의 순서와 1:1로 정확히 매칭되어야 해.
5. 리뷰에 명시된 별점(score)을 추출해.
6. 결과는 반드시 아래의 JSON 형식으로만 출력하고, 다른 설명은 하지마.

[출력 형식]
{
  "review": "리뷰 원문",
  "aspect": ["추출된 속성 리스트"],
  "label": [각 속성에 대응하는 1 또는 0 리스트],
  "score": 별점숫자
}
"""
  human = f"""
[리뷰 원문]
{review}

[후보 속성]
{aspect_list}

[별점 숫자]
{score}

[수정 요청 피드백]
{feedback}
"""

  resp = analyzer_llm.invoke([SystemMessage(content=sys),
                       HumanMessage(content=human)])
  data_dict = json.loads(resp.content)
  result = data_dict
  return {
      "messages": [AIMessage(content=f"[Analyzer Result]\n{resp.content}")],
      "result": result,
      "current_agent": "analyzer",
  }

# %%
state = analyzer_node(state)

# %%
state["result"]

# %% [markdown]
# * Critic Agent

# %%
state: ReviewState = {
    "input_review": '보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.',
    "score": 3,
    "result": {'id': 1,
   'review': '보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.',
   'aspect': ['보습', '가격', '향'],
   'label': [1, 0, 1],
   'score': 3},
    "aspect_list": ['보습', '가격', '향', '포장']
}

# %%
def critic_node(state: ReviewState):

  review = state.get("input_review") or ""
  aspect_list = state.get("aspect_list") or []
  result = state.get("result") or ""
  criti_score = state.get("criti_score") or ""
  current_num = state.get("current_num") or 0

  sys = """
너는 리뷰 분석 결과의 정확성을 검증하는 품질 관리(QA) 전문가야.
Analyzer가 추출한 결과가 리뷰 원문의 내용과 논리적으로 일치하는지 검토해줘.

#검토 지침
1. 일관성: 추출된 'aspect'가 리뷰 원문에 실제로 언급된 내용인지 확인해. (언급되지 않은 속성은 포함되지 않아야 함)
2. 정확성: 각 'aspect'에 매칭된 'label'(1: 만족, 0: 불만족)이 리뷰의 맥락과 맞는지 확인해.
3. 형식: 결과가 약속된 JSON 형식을 유지하고 있는지 확인해.
4. 순서: **[중요] 추출된 'aspect'들은 [후보 속성]에 나열된 상대적 순서를 유지해야 해.**
   - 리뷰에 언급되지 않아 제외된 속성이 있더라도, 남아있는 속성들 간의 앞뒤 순서가 [후보 속성] 리스트의 순서와 일치하면 OK야.
   - 예: 후보가 [A, B, C, D]이고 추출이 [A, C]라면 순서가 맞는 것으로 간주함.

#판단 기준
- 분석 결과에 논리적/형식적 오류가 없는지
- 리뷰에 언급되지 않은 속성이 포함되어 있지는 않은지
- **존재하는 속성들끼리의 순서가 후보 리스트의 우선순위와 일치하는지**

#출력
[FEEDBACK]
- ...
- ...
[VERDICT]
VERDICT: OK
또는
VERDICT: REVISE
"""

  human = f"""
[리뷰 원문]
{review}

[후보 속성]
{aspect_list}

[Analyzer의 분석 결과]
{result}
"""
  resp = criti_llm.invoke([SystemMessage(content=sys),
                       HumanMessage(content=human)])
  current_num = current_num + 1
  return {
        "messages": [AIMessage(content=f"[CRITIC RESULT]\n{resp.content}")],
        "criti_score": resp.content,
        "current_num" : current_num,
        "current_agent": "critic",
    }

# %%
state = critic_node(state)

# %%
state["criti_score"]

# %% [markdown]
# ## 별점 1~2점인 요소들을 딕셔너리로 반환하는 함수

# %%
# 별점 1~2점인 요소가 있다면 딕셔너리로 반환하는 함수
def select_low_score_reviews():
    conn = sqlite3.connect("user_review_db.db")
    cursor = conn.cursor()

    cursor.execute("""
        SELECT id, review, aspect, label, score, updated_at
        FROM user_reviews
        WHERE score IN (1, 2)
        ORDER BY score ASC, updated_at DESC
    """)
    rows = cursor.fetchall()
    conn.close()

    reviews = []
    for row in rows:
        id_, review, aspect, label, score, updated_at = row

        # aspect, label은 TEXT로 저장되어 있으므로 리스트로 변환
        # (분석 전이면 NULL일 수 있어서 안전하게 처리)
        try:
            aspect_parsed = ast.literal_eval(aspect) if aspect else None
        except (ValueError, SyntaxError):
            aspect_parsed = aspect  # 파싱 실패 시 원본 문자열 유지

        try:
            label_parsed = ast.literal_eval(label) if label else None
        except (ValueError, SyntaxError):
            label_parsed = label

        reviews.append({
            "review": review,
            "aspect": aspect_parsed,
            "label": label_parsed,
        })

    return {
        "total_count": len(reviews),
        "reviews": reviews,
    }

# %%
tt = {
    "total_count": 0,
    "reviews": []
}

# %%
tt = select_low_score_reviews()

# %%
tt
# Out:
# {'total_count': 33,
#  'reviews': [{'review': '홈쇼핑 광고에서도 정말 많이 하고 많은 분들이 궁금해하셨던 바로 그 제품 사용 후기 가져왔습니다. 저도 구매를 직접 해서 써 봤는데 좋은 점이 없는 것 같아서 알려드리고 싶었어요... 단점이 너무 많은 제품이라.. 무슨 말부터 시작을 해야 될 지 모르겠습니다. 일단 이 제품을 사게 된 계기는 홈쇼핑 광고를 보고 샀어요. 구성이 너무 좋아서 구매를 했습니다. 배송은 빨리 왔고 오자 마자 기대를 가지고 사용하게 되었어요. 하지만 하는 내내 풍기는 이상한 냄새에 머리가 아팠습니다. 두피에 자극도 있어서 지금 너무 가려운 것 같습니다...ㅠㅠ 약을 먹어도 가려움이 없어지지 않네요. 염색제 색상도 마음에 들지 않았고 발색도 너무 어둡게 나온 것 같습니다. 결론은 저는 추천하고 싶지 않은 제품이네요~ 다른 염색약 사용하시는 것이 더 좋을 것 같다는 게 제 결론입니다..!!',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 1, 0, 0]},
#   {'review': '괜히 처음부터 대량 구매한 것 같습니다. 제 피부에는 잘 안 맞는지 피부결이 탁하고 거친 느낌이네요. 주위에서 피부 관리해야겠다고 그래요. 꾸준히 믿고 사용하려고 많이 샀는데 후회 되네요.',
#    'aspect': [],
#    'label': []},
#   {'review': '향수 필요해서 찾아 보다가 이 제품 할인 해서 구매하게 되었는데 품질이 생각보다 좋지는 않네요!! 저는 사용하고 좋지 않아서 후기 작성합니다... 유통기한도 엄청 짧은 제품을 받아서 기분이 안 좋고 용기가 너무 무거워 좋지 않네요.... 향은 기대보다 좋지 않아서 아쉬운 것 같습니다.. 잔향도 살짝 너무 별로에요... 괜히 산 것 같다는 생각이 듭니다!! 가성비 없는 것 같아요! 이거 뿌리고 동생한테 물어보니까 향이 별로라고 하는 걸 보면 저만 그렇게 느끼는 게 아닌 것 같습니다...!! 추천 하고 싶지 않습니다! 저는 그냥 다른 향수 구입해서 사용하고 있네요~',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '시향 못해 봤는데 OOO이 유명한 제품이라 믿고 구입했어요. 향이 고급스럽기 보다는 익숙한 남자 스킨향이 느껴지네요. 무겁고 중후한 향이길 기대했는데 기대한 만큼 아쉬움이 크게 다가오네요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '처음 사용할땐 청량감이 있었는데 한참 쓰니깐 청량감이 없네요. 그리고 머리카락이 뻣뻣해져서 오일을 발라야 해요',
#    'aspect': [],
#    'label': []},
#   {'review': '평소에 뿌리는 헤어에센스를 사용하다가 좀 더 영양을 주려고 오일 제형의 에센스를 한 번 구입해봤어요. 제가 머리숱이 좀 많은 편이다보니 어떤 헤어제품이나 한 번에 많은 용량을 써야하는데 이 제품은 특히 한 번 펌핑에 굉장히 양이 작게 나오네요. 한 번에 10번 이상 펌핑하는 것 같아서 불편해요. 좀 많이 나오면 편할텐데요. 오일치고는 많이 끈적하지 않아서 머리에 바를 때는 좋았어요. 별로 잔여감도 없고 그건 점수를 줄 수 있을 것 같아요. 다만 그냥 바를 때만 좋고 뭔가 발라서 머릿결이 개선이 된다든가 하는건 기대하기 어려울 것같아요. 1+1 세일을 한다면 모를까 정가로 구매하기엔 좀 아까울 것 같아요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 1, 0]},
#   {'review': '홈쇼핑에서 구매 했는데 다른 곳보다 비싼 가격에 양은 적어 금방 쓰게 되네요. 건조한 피부에 촉촉하지 않고 건조한 느낌이 아쉽네요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 1, 1]},
#   {'review': '처음 사보는데요. 값이 생각보다 비싸네요. 제형이 반죽할 때 좀 덩어리가져서 잘 안풀려요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '가격이 비싼편이네요. 처음 바르면 알콜냄새가 살짝 올라와서 별로예요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '유통기한이 짧은 제품이 와서 아쉽습니다. 정품은 속 뚜껑을 열 때 스티커가 있다고 하는데 이 제품은 없습니다. 팩트 테두리가 말라서 갈라져 있어 품질이 불량입니다. 자세한 후기는 사용해보고 다시 올리겠습니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '쿠폰 적용을 못해서 비싸게 구매했어요. 그런데 염색해보니 색감이 잘 나오지 않아서 별로예요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '와이프 선물로 구매했어요. 와이프가 발라보니 얼굴이 당긴다고 하네요. 용량도 작은데 촉촉하지도 않고 비싸서 만족스럽지 않네요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '햇빛 알레르기가 목과 팔에 심해 햇빛에 나갈 때는 바르는데 살짝 가려움증이 생기네요. OOO나 OO등 비싼 제품에 비교할 때 가성비가 떨어집니다. 끈적임이 많고 무엇보다 자외선차단 잘 되지 않네요. 요즘같이 마스크 쓸 때 색이 묻어나니 신경쓰입니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '양이 넉넉해서 오래 쓸 수 있을 거 같고 저렴해서 구매했어요. 올인원이라 건조하지 않을까 걱정했는데 생각했던 대로 촉촉하지 않네요. 향도 별로고요. 톤업 효과도 없고 진정 효과도 없는 거 같아요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 1, 0, 0]},
#   {'review': '여름에는 괜찮고 겨울 바디용으로 수분감이 좀 부족한 제품입니다. 겨울이면 몸이 건조하고 각질이 일어나서 바디 제품 꼭 발라야 하는 피부입니다. 제가 새로운 제품을 좋아해서 안 써본 제품이라 이 제품으로 주문하게 되었어요. 택배 받고 바로 사용했어요. 처음 발랐을 때만 촉촉한 느낌이었고 금방 건조함이 느껴집니다. 겨울에 쓰기에는 수분감이 부족한 제품인 것 같아요. 여름에는 바르기 괜찮을 듯하네요. 마음에 들었으면 좋았을 텐데... 겨울용으로 구입한 저는 이 제품 추가 주문은 안 할 생각입니다.',
#    'aspect': ['보습'],
#    'label': [0]},
#   {'review': '새로 한번 써보려고 구매했는데요. 팩이 별로네요. 피부결도 개선이 없고 별 효과가 없어요. 다른 팩보다 보습효과가 그렇게 좋은지도 모르겠어요. 가격도 그렇게 저렴하지 않네요.',
#    'aspect': ['보습', '가격'],
#    'label': [0, 0]},
#   {'review': '예전에는 가격이 괜찮았는데 지금은 가격이 너무 비싸네요. 가격이 올라서 이제는 구매 안 할 것 같아요.',
#    'aspect': ['가격'],
#    'label': [0]},
#   {'review': '늘 쓰던 제품이 품절이라 새로운 제품을 시도해보고 싶어서 구입했어요. 근데 양도 너무 작고 바르고 나면 번짐이 심해 팬다가 되서 안쓰게 되네요. 가격도 싸지 않았는데 괜히 샀어요. 마스카라 솔이 자그마하니 잘 발라집니다. 솔이 큰거는 바를때 묻는데 이 마스카라 솔은 작아서 묻지도 않아서 사용하기 편하네요. 깔끔하게 잘 발라지고 번짐도 없습니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '바를 때 제형이 끈적이고 부드럽게 발리지는 않네요. 피부가 약간 건조해져서 재구매는 생각해봐야겠네요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '향수의 잔향을 좋아하는데 이 향수는 지속력이 짧아서 잔향을 맡기 어렵네요. 지속력이 길진 않아서 아쉽네요. 잔향 맡기 전에 향이 금방 사라지네요. 향이 금방 사라져서 자주 뿌리다 보면 용량이 작은 편이라 금방 쓰겠어요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '부드러운 발림성을 가지고 있긴 하지만 발림성이 좋다보니 흡수까지는 시간이 좀 오래 걸리네요 겉도는 느낌도 들고 보습력이 좋은것도 아니네요. 몇번 덧 발라주는게 보습으로는 효과가 있을거 같습니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '예전에는 뜯으면 약간 수분이 있었는데 제형이 너무 고체화 되고 양도 줄은 거 같습니다.',
#    'aspect': ['보습'],
#    'label': [0]},
#   {'review': '오늘 제품을 받고 처음 사용해 봤는데 청소하면서 돌아다녔습니다. 사용 후에 얼굴이 촉촉하지는 않았고 생각보다 제품에 콜라겐 성분이 부족한 것 같습니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '여드름 때문에 사용하는 중입니다. 조금 당기네요. 에센스랑 같이 사용하면 덜 당깁니다. 효과는 더 써봐야 알 것 같아요.',
#    'aspect': [],
#    'label': []},
#   {'review': 'OO멀티밤을 입술 주위에 발라봤는데 보습이 잘 되진 않네요. 미스트도 향이 별로고요. 오일은 번들거려요. 용량도 작아요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '이것저것 잘 챙겨바르는 편이 아닌데 이 제품이 한 번에 해결된다고 해서 구매해 봤습니다. 그런데 생각보다 촉촉하지 않네요. 할인 기간을 놓치는 바람에 비싸게 샀는데 가격대비 용량이 작은 거 같아요.',
#    'aspect': ['보습', '가격'],
#    'label': [0, 0]},
#   {'review': '세정력은 좋은데 향긋한 허브 향이 아니고 약품 냄새 같아서 재구매 의사는 없습니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '편하게 사용하시라고 시골에 계신 아빠에게 선물로 보내드렸네요. 발라보니 촉촉하지 않다고 하시네요. 얼굴 땡김도 있고 건조하고 향도 강하다 하십니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '진정만 해주네요. 보습은 1도 없습니다. 제형이 묽어서 발림성 좋고 사용감 가볍습니다. 바로 흡수되고 흡수되자마자 말라서 건조합니다. 진정작용은 나름 역할을 하는 것 같습니다.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '주변에서 추천받아 주문해봤는데 유통기한도 짧고 설명서도 없어요. 물건만 보내와서 뒷면에 영어 설명보고 사용해야 할 것 같네요. 샘플도 하나도 없어요.',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 0, 0, 0]},
#   {'review': '유명 뷰티 인플루언서가 추천한 선크림이 특히 잘나가는 OO의 붉은기 진정 크림 OOO 크림을 사용해 봤어요. 먼저 고백할게요. 저는 얼굴에 붉은기가 원래 없어서 붉은기가 진정되는 효과는 알 수가 없었어요. 그러면서 왜 샀냐고 물으신다면... 싸기도 하고 OO 화장품이 궁금하기도 했거든요. 그런데 금액이 저렴한 데에는 다 그럴 만한 이유가 있나 봐요. 바르고 나서 멀쩡한 얼굴에 여드름이 올라왔네요. 아무래도 제품에 유분기가 많은 편이라서 그런가 봐요. 지성피부인 분들은 피하시는 게 좋겠어요. 오늘도 피해야 할 화장품 리스트에 +1 하고 저는 이만 총총...',
#    'aspect': ['보습', '가격', '향', '포장'],
#    'label': [0, 1, 0, 0]},
#   {'review': '싼맛에 사용하고 있는데 ㅇㅇㅇ 팩치고는 수분감도 적고 밀착력도 떨어지고 기능을 제대로 못하네요. 팩 분리할때도 다른 팩에 비해 손이 많이 가서 사용하기 불편하네요. 딱히 수분충전되는 느낌이 없네요.',
#    'aspect': ['보습', '가격'],
#    'label': [0, 1]},
#   {'review': '바르고 끈적여서 신경이 많이 쓰이고 피부가 좋아지지 않네요. 성분도 안 좋은 것 같고 용량도 아쉬워 재구매는 없습니다.',
#    'aspect': [],
#    'label': []}]}

# %% [markdown]
# * Supervisor Agent

# %%
def supervisor_node(state: ReviewState):
  print("-다음 경로 탐색중...-")

  if not state.get("result"):
    next_step = "analyzer"

  elif not state.get("current_num"):
    next_step = "critic"

  else:
    criti = state.get("criti_score") or ""

    if "VERDICT: OK" in criti:
      next_step = "end"

    elif "VERDICT: REVISE" in criti and state.get("current_num") < state.get("max_num"):
      print("-!재분석이 요구됩니다.!-")
      next_step = "analyzer"

    else:
      next_step = "end"

  print(f"-{next_step}으로 이동합니다.-")

  return {
      "next_step": next_step,
      "current_agent": "supervisor",
  }

# %% [markdown]
# * route_next 함수

# %%
def route_next(state: ReviewState):
    return state["next_step"]

# %% [markdown]
# * 그래프

# %%
builder = StateGraph(ReviewState)

builder.add_node("analyzer", analyzer_node)
builder.add_node("critic", critic_node)
builder.add_node("supervisor",supervisor_node)

builder.add_edge(START, "supervisor")

builder.add_conditional_edges("supervisor", route_next,
    { "analyzer": "analyzer",
        "critic": "critic", "end": END }
)

builder.add_edge("analyzer", "supervisor")
builder.add_edge("critic", "supervisor")

app = builder.compile()

# %%
app

# %%
# 테스트 입력 준비
test_input: ReviewState = {
    "messages":     [],
    "input_review": "보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.",
    "score":        4,
    "aspect_list":  ["보습", "가격", "향", "포장"],
    "result":       {},
    "criti_score":  "",
    "current_num":  0,
    "max_num":      3,
    "next_step":    None,
}

# Agent 실행 (실행과 동시에 LangSmith로 trace 자동 전송)
result = app.invoke(test_input)

# 결과 확인
print("===== 최종 분석 결과 =====")
print(result["result"])
print("\n===== Critic 평가 =====")
print(result["criti_score"])
print(f"\n===== 반복 횟수: {result['current_num']} =====")

# %% [markdown]
# #### **1) State 보완**

# %%
ReasonCode = Literal["OUTPUT_ERROR", "SCOPE_ERROR", "EVIDENCE_ERROR", "QUALITY_ERROR", "OK"]

class ReviewState(TypedDict):
    messages: Annotated[list, add_messages]
    input_review: str
    max_num: int
    current_num: int
    score: int
    next_step: Optional[Literal["analyzer", "critic", "end"]]
    result: dict
    aspect_list: List[str]
    criti_score: str

    # 추가
    current_agent: Optional[str]

    reason_code: Optional[ReasonCode]
    repair_directive: str

# %%
visor_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
analyzer_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
criti_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)

# %% [markdown]
# #### **2) Agent 노드 준비**

# %%
# 정책 및 필요 함수 준비 : 아래 내용을 수정해서 사용하세요.

REASON_CODES = {"OUTPUT_ERROR", "SCOPE_ERROR", "EVIDENCE_ERROR", "QUALITY_ERROR", "OK"}
RETRYABLE = {"OUTPUT_ERROR", "SCOPE_ERROR", "EVIDENCE_ERROR"}

REPAIR_TEMPLATES = {
    "OUTPUT_ERROR": "dict 1개만 출력. 코드블록/설명 없이 items 구조와 label(0/1)을 맞춰라.",
    "SCOPE_ERROR": "aspect는 보습, 가격, 향, 포장만 사용하라. 다른 표현은 가장 가까운 값으로 매핑하라.",
    "EVIDENCE_ERROR": "리뷰 원문에 실제 언급되지 않은 aspect는 제외하라.",
    "QUALITY_ERROR": "리뷰에 없는 내용을 만들지 말고, 애매하면 해당 aspect는 제외하라."
}

# 딕셔너리 파싱 함
def parse_dict(text, default):
    try:
        return ast.literal_eval(text)
    except:
        return default

# %% [markdown]
# * Analyzer Agents 보완

# %%
aspect_list = ['가격', '구성', '제형 밀도', '향', '사용감', '지속력', '디자인', '만족도', '보습', '휴대성', '배송', '발림성', '용량', '사은품', '포장', '커버력', '피부표현', '세팅력', '발색', '소독효과', '흡수력', '유통기한', '유통 기한', '사이즈', '편의성', '품질', '색감', '제형', '피부타입', '유분감', '유효기간', '자외선 차단', '톤업', '진정', '크기', '피부결', '세정력', '번짐', '밀착력', '색상', '위생', '손상케어', '주름개선', '자극', '클렌징', '효과', '할인', '재구매', '성분', '피부']

# %%
state: ReviewState = {
    "input_review": '보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.',
    "score": 0,
    "result": "",
    "aspect_list": aspect_list
}

# %%
def analyzer_node(state: ReviewState):
    review = state.get("input_review") or "" # 리뷰 원문
    aspect = state.get("aspect_list") or []   # 후보 속성 리스트
    score = state.get("score") or 0   # 리뷰 별점
    directive = state.get("repair_directive") or ""
    retry_cnt = state.get("current_num") or 0
    feedback  = directive if directive else "없음 (최초 분석)"

    sys = """
너는 리뷰 분석 전문가야. 다음 지침에 따라 입력받은 사용자의 리뷰를 분석해줘.
만약 [수정 요청 피드백]이 제공된다면, 이전의 실수를 교정하여 결과를 다시 작성해야 해.

[지침]
1. 제시된 [후보 속성] 중에서 리뷰 내용과 일치하는 것을 추출해. **단, '성능', '효과'처럼 포괄적인 단어가 쓰였더라도 문맥상 화장품의 기능(예: 보습력)을 뜻한다면 유연하게 해석해서 해당 후보 속성으로 매칭해줘.**
'다 좋다', '전부 좋다' 등 전반적 긍정 표현은 모든 후보 속성에 대한 긍정으로 해석해.'성능', '효과'처럼 포괄적인 단어도 문맥상 화장품 기능을 뜻한다면 유연하게 매칭해줘.
2. aspect 리스트에 담긴 속성의 순서는 반드시 [후보 속성]에 나열된 순서를 유지해야 해.
3. 각 속성에 대한 만족도를 판별해. 만족/긍정은 1, 불만족/부정은 0이야.
4. label 리스트의 값은 aspect 리스트의 순서와 1:1로 정확히 매칭되어야 해.
5. [중요: 별점 산정]
- 입력된 [별점 숫자]가 0보다 크면 그 숫자를 그대로 사용해.
- 입력된 [별점 숫자]가 0이라면, 리뷰 원문의 뉘앙스를 분석하여 네가 직접 1~5점 사이의 별점을 책정해.
(매우 만족: 5, 만족: 4, 보통: 3, 불만족: 2, 매우 불만족: 1)
6. 결과는 반드시 아래 JSON 형식으로만 출력하고, 다른 설명은 하지마.

[출력 형식]
{
"review": "리뷰 원문",
"aspect": ["추출된 속성 리스트"],
"label": [각 속성에 대응하는 1 또는 0 리스트],
"score": 별점 산정 숫자
}
"""

    human = f"""
    [리뷰 원문]
    {review}

    [후보 속성]
    {aspect}

    [별점 숫자]
    {score}

    [수정 요청 피드백]  ← {retry_cnt}회차 재시도
    {feedback}
    """

    resp = analyzer_llm.invoke([
        SystemMessage(content=sys),
        HumanMessage(content=human)
    ])

    content = resp.content.strip()
    content = content.replace("```json", "").replace("```", "").strip()

    data_dict = json.loads(content)

    return {
        # 실행 로그 누적
        "messages": [AIMessage(content=f"[Analyzer Result]\n{resp.content}")],
        "next_step": "supervisor",
        "result": data_dict,        # Analyzer가 만든 분석 결과 JSON을 넣음
        "current_agent": "analyzer", # 현재 실행 중인 Agent (Trace 가독성용)
        "criti_score": " ",
        "reason_code": []
    }

# %%
state = analyzer_node(state)

# %%
state["result"]

# %% [markdown]
# * Critic Agent 보완

# %%
state: ReviewState = {
    "input_review": '보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.',
    "score": 0,
    "result": {'id': 1,
   'review': '보습력이 정말 좋아요. 향도 괜찮지만 가격은 조금 비싸요.',
   'aspect': ['가격', '향'],
   'label': [0, 1],
   'score': 3},
    "aspect_list": ['보습', '가격', '향', '포장']
}

# %%
def critic_node(state: ReviewState):
    input_review = state.get("input_review", "")
    result = state.get("result", {})
    aspect_list = state.get("aspect_list", [])
    reason_code = state.get("reason_code", None)


    sys_msg = """
    # 역할: 너는 리뷰 분석 결과 정확성을 면밀히 검토하는 검증 Agent.
    - analyzer 가 추출한 결과가 리뷰 원문과 논리적으로 일치하는지 검토해줘.

    # 지침
    1. 일관성: 추출된 'aspect'가 실제 리뷰 원문에 언급된 내용인지 확인. (언급되지 않은 속성은 포함 X)
            - 직접 언급되지 않았더라도 문맥 상 의미가 통하면 허용. (예: '효과 좋다' -> '보습' 허용)
            - 리뷰에 전혀 관련 없는 속성이 포함되어 있다면 오류.
    2. 정확성: 각 'aspect'에 매칭된 'label' (1: 만족, 0: 불만족)이 리뷰의 맥락과 맞는지 확인.
    3. 형식: 결과가 JSON 형식을 유지하고 있는지 확인.
    4. 순서: 추출된 'aspect' 들은 [후보 속성]에 나열된 상대적 순서를 반드시 유지해야함.
            - 일부 속성이 빠지더라도 남은 속성들 사이의 순서는 유지되어야함.
            - 예: 후보가 [A, B, C, D]이고 추출이 [A, C]라면 순서가 맞는 것으로 판단.


    # 출력 형식
    검토 후 반드시 아래 형식으로만 출력. 다른 설명은 하지마.
    [FEEDBACK]
    - (문제가 있으면 구체적으로, 없으면 '문제 없음'으로 작성)
    [VERDICT]
    reason_code: 아래 중 하나만 출력 (예: reason_code: NONE)
    - OK: 분석 결과에 문제 없음.
    - OUTPUT_ERROR: 출력 형식 또는 JSON 구조 오류.
    - SCOPE_ERROR: 관련 없는 속성이 포함됨.
    - EVIDENCE_ERROR: 후보 속성에는 있지만 리뷰 원문에 언급이 없는 속성이 포함됨.
    - QUALITY_ERROR: 긍정/부정 판단 오류.
    """

    human_msg = f"""
    [리뷰 원문]
    {input_review}


    [후보 속성]
    {aspect_list}


    [Analyzer 분석 결과]
    {result}


    [reason_code]
    {reason_code}
    """

    response = criti_llm.invoke([SystemMessage(content=sys_msg), HumanMessage(content=human_msg)])
    feedback_match = re.search(r"\[FEEDBACK\]\s*(.*?)\s*\[VERDICT\]", response.content, re.DOTALL)
    reason_match = re.search(r"reason_code:\s*(\w+)", response.content)


    feedback = feedback_match.group(1).strip() if feedback_match else "피드백 추출 실패"
    reason = reason_match.group(1).strip() if reason_match else "UNKNOWN"

    return {
        "messages": [AIMessage(content=f"[CRITIC RESULT] \n {response.content}")],
        "criti_score": feedback,
        "reason_code": reason,
        "next_step": "supervisor",
        "current_agent": "critic"
    }

# %%
state = critic_node(state)

# %%
state["criti_score"]

# %% [markdown]
# * Supervisor Agent 보완

# %%
def supervisor_node(state: ReviewState):
    print("-경로 탐색-")
    criti_score = state.get("criti_score")
    current_cnt = state.get("current_num", 0)
    max_cnt = state.get("max_num", 3)
    result = state.get("result")
    reason = state.get("reason_code")
    print(f"current_cnt: {current_cnt}")
    if not result:
        print("analyzer")
        return {
            "next_step": "analyzer",
            "current_agent": "supervisor"
        }

    elif not criti_score is None and state.get("current_agent") == "analyzer":
        print("critic")
        return {
            "next_step": "critic",
            "current_agent": "supervisor",
            "current_num": current_cnt + 1
        }

    elif reason == "OK":
        print("end")
        return {
            "next_step": "end",
            "current_agent": "supervisor",
        }

    elif not reason == "OK" and current_cnt < max_cnt:
        directive = reason + "가이드에 맞춰 다시 분석하세요."
        print("재작성 필요 analyzer")
        return {
            "next_step": "analyzer",
            "current_agent": "supervisor",
            "repair_directive": directive,
            "current_num": current_cnt + 1
        }
    else:
      print(f"분석 중단 (사유: {reason} / 시도: {current_cnt})")
      return {
          "next_step": "end",
          "current_agent": "supervisor",
      }

# %% [markdown]
# * route_next 함수

# %%
def route_next(state: ReviewState):
    return state["next_step"]

# %% [markdown]
# * 그래프

# %%
builder = StateGraph(ReviewState)

builder.add_node("analyzer", analyzer_node)
builder.add_node("critic", critic_node)
builder.add_node("supervisor",supervisor_node)

builder.add_edge(START, "supervisor")

builder.add_conditional_edges("supervisor", route_next,
    { "analyzer": "analyzer",
        "critic": "critic", "end": END }
)

builder.add_edge("analyzer", "supervisor")
builder.add_edge("critic", "supervisor")

app = builder.compile()

# %%
app

# %% [markdown]
# * 실행 테스트

# %%
review = '''
보습력은 소문대로 정말 쫀쫀하고 좋은데, 향이 너무 강해서 머리가 아파요. 아, 포장은 꼼꼼하게 잘 왔어요!
'''
# 테스트 입력 데이터
test_input = {
    "input_review": review,
    "aspect_list": aspect_list,
    "score": 0,
    "max_num": 3,
    "current_num": 0,
    "result": "",
    "criti_score": ""
}

# %%
result = app.invoke(test_input)

# %%
print(result["result"])

# %% [markdown]
# ## 별점 1~2점 리뷰에 대한 피드백을 주는 Agent

# %%
from typing import Annotated, List, TypedDict
import operator

class AnalyzerState(TypedDict):
    messages: Annotated[list, add_messages]
    review: str
    aspect: List[str]
    label: List[int]
    next_node: List[str]
    result_list: Annotated[List[str], operator.add]
    final_result: str

# %%
apects = ['가격', '구성', '제형 밀도', '향', '사용감', '지속력', '디자인', '만족도', '보습', '휴대성', '배송', '발림성', '용량', '사은품', '포장', '커버력', '피부표현', '세팅력', '발색', '소독효과', '흡수력', '유통기한', '유통 기한', '사이즈', '편의성', '품질', '색감', '제형', '피부타입', '유분감', '유효기간', '자외선 차단', '톤업', '진정', '크기', '피부결', '세정력', '번짐', '밀착력', '색상', '위생', '손상케어', '주름개선', '자극', '클렌징', '효과', '할인', '재구매', '성분', '피부']

# %%
router_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
price_llm = ChatOpenAI( model="gpt-4.1-mini", temperature=0.7)
performance_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.3)
Texture_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
Design_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.7)
Service_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=1)

# %%
test = {
    "review": '홈쇼핑 광고에서도 정말 많이 하고 많은 분들이 궁금해하셨던 바로 그 제품 사용 후기 가져왔습니다. 저도 구매를 직접 해서 써 봤는데 좋은 점이 없는 것 같아서 알려드리고 싶었어요... 단점이 너무 많은 제품이라.. 무슨 말부터 시작을 해야 될 지 모르겠습니다. 일단 이 제품을 사게 된 계기는 홈쇼핑 광고를 보고 샀어요. 구성이 너무 좋아서 구매를 했습니다. 배송은 빨리 왔고 오자 마자 기대를 가지고 사용하게 되었어요. 하지만 하는 내내 풍기는 이상한 냄새에 머리가 아팠습니다. 두피에 자극도 있어서 지금 너무 가려운 것 같습니다...ㅠㅠ 약을 먹어도 가려움이 없어지지 않네요. 염색제 색상도 마음에 들지 않았고 발색도 너무 어둡게 나온 것 같습니다. 결론은 저는 추천하고 싶지 않은 제품이네요~ 다른 염색약 사용하시는 것이 더 좋을 것 같다는 게 제 결론입니다..!!',
    "aspect": ["보습", "가격", "향"],
    "label": [0, 0, 0],
    "next_node": [],
    "result": [],
    "final_result": ""
}

# %%
def router_node(state: AnalyzerState) :
    print("--- [Router] 의도 분류 중... ---")
    aspect = state.get("aspect") or []
    label = state.get("label") or []

    # 2. 프롬프트 구성
    sys_msg = '''
너는 고객 리뷰의 불만 사항을 파악하고 해결할 전문 부서를 배정하는 라우터(Router) 에이전트야.
입력된 [aspect] 리스트와 [label] 리스트의 규칙을 분석하여, 불만족으로 평가된 속성을 해결할 전문가 에이전트 목록을 출력해.

[전문가 그룹 및 담당 속성]
1. price_node: 가격, 할인, 가성비, 구성
2. performance_node: 보습, 커버력, 발색, 자외선 차단, 톤업, 진정, 세정력, 손상케어, 주름개선, 클렌징, 효과, 피부결, 피부, 품질, 성분, 소독효과
3. texture_node: 발림성, 흡수력, 사용감, 제형 밀도, 제형, 유분감, 밀착력, 번짐, 자극, 향
4. design_node: 디자인, 색감(색상), 사이즈(크기), 휴대성, 편의성, 위생, 포장
5. service_node: 배송, 만족도, 재구매, 피부타입, 사은품

[분석 및 라우팅 지침]
1. 매칭 규칙: [aspect]와 [label]의 요소는 같은 인덱스(위치)로 1:1 매칭되어 있어. (예: aspect[1]의 만족도는 label[1]의 값과 같음)
2. 불만족 식별: [label] 값이 1이면 '만족', 0이면 '불만족'을 의미해. [label] 리스트에서 값이 0인 인덱스를 모두 찾아.
3. 속성 추출: 찾아낸 인덱스와 동일한 위치에 있는 단어들을 [aspect] 리스트에서 추출해.
4. 에이전트 매칭: 추출된 불만족 속성 단어들이 어느 [전문가 그룹]에 속하는지 대조하여 해당 에이전트(LLM)의 이름을 매칭해.
5. 중복 제거: 여러 속성이 하나의 에이전트에 매칭되더라도, 최종 출력 리스트에는 에이전트 이름이 중복되지 않도록 고유한(unique) 값만 남겨.
6. 우선순위 정렬: 제품의 핵심 기능과 안전이 최우선이므로, 매칭된 리스트에 "performance_llm"이나 "Texture_llm"이 포함되어 있다면 맨 앞에 오도록 정렬해.
7. 예외 처리: 만약 [label] 리스트에 0(불만족)이 하나도 없다면, 전반적인 감사 및 고객 관리를 위해 ["Service_llm"]을 출력해.

[출력 형식]
반드시 쌍따옴표가 포함된 올바른 JSON 리스트 형식으로만 응답해. 빈 리스트([])나 부가 설명은 절대 출력하지 마.
예) ["performance_node", "texture_node", "design_node"]
    '''

    user_msg = f"""
[aspect]
{aspect}

[label]
{label}
"""

    # 3. llm 호출
    response = router_llm.invoke([SystemMessage(content=sys_msg),
                                  HumanMessage(content=user_msg)])

    # 4. 파싱 및 예외 처리
    content = response.content.strip()

    if content.startswith("```"):
        content =content = content.replace("```json", "").replace("```", "").strip()

    try:
        destination = json.loads(content)
    except json.JSONDecodeError:
        print(f"파싱 에러 발생, 원본 출력: {content}")
        destination = ["Service_llm"]

    # 5. State 업데이트
    return {"next_node": destination}

# %%
test = router_node(test)

# %%
test

# %%
def performance_node(state: AnalyzerState):
    # 1. State로 부터 필요한 정보 가져오기
    review = state.get("review") or ""
    aspect = state.get("aspect") or []
    label = state.get("label") or []
    result = state.get("result_list") or[]

    # 2. 프롬프트 구성
    sys_msg = '''
너는 제품의 '효능, 성분, 품질' 개선을 담당하는 제품 개발 전문가(performance_llm)야.
입력된 [aspect], [label] 데이터와 [review] 원문을 함께 분석하여, 네가 담당하는 속성 중 불만족(0)으로 평가된 항목에 대한 구체적인 원인 분석과 맞춤형 해결 방안을 제시해.

[담당 속성 영역]
보습, 커버력, 발색, 자외선 차단, 톤업, 진정, 세정력, 손상케어, 주름개선, 클렌징, 효과, 피부결, 피부, 품질, 성분, 소독효과

[분석 및 해결 지침]
1. 타겟 추출: [aspect]와 [label] 리스트는 같은 인덱스로 1:1 매칭되어 있어. [label] 값이 0(불만족)인 항목 중, 너의 [담당 속성 영역]에 해당하는 단어만 필터링해.
2. 리뷰 문맥 파악: 필터링된 속성들이 [review] 원문에서 구체적으로 어떻게 묘사되었는지 파악해 (예: 단순히 '발색' 불만이 아니라 "발색이 너무 어둡게 나왔다" 등 사용자의 실제 경험 확인).
3. 맞춤 해결책 제시: 리뷰 원문에서 파악한 정확한 불만 원인을 바탕으로, 화장품 연구원 및 제품 기획자 관점에서 구체적이고 실현 가능한 개선 방안을 도출해.
4. 영역 제한: 너의 담당 속성이 아닌 불만족 항목(예: 냄새, 배송, 가격 등)은 철저히 무시하고 언급하지 마.

[출력 형식]
반드시 아래의 텍스트(문자열) 형식으로만 응답해. JSON이나 마크다운 코드 블록은 절대 사용하지 마. 부가적인 인사말이나 설명도 금지해.

[개선 대상 속성]: 불만족으로 확인된 너의 담당 속성들을 쉼표로 구분하여 나열 (예: 보습, 발색)

- 속성: 불만족 속성 이름 1
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 성분 변경, 배합 비율 조정 등 연구원 관점의 실질적이고 전문적인 개선 방안

- 속성: 불만족 속성 이름 2
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 성분 변경, 배합 비율 조정 등 연구원 관점의 실질적이고 전문적인 개선 방안
    '''
    user_msg = f'''
    [review]
    {review}

    [aspect]
    {aspect}

    [label]
    {label}
    '''
    # 3. llm 호출
    response = performance_llm.invoke([
        SystemMessage(content=sys_msg),
        HumanMessage(content=user_msg)
    ])

    result.append(response.content)
    # 4. State 업데이트
    return {

      "messages": [response],

      "result_list": [response.content]

    }

# %%
test = performance_node(test)

# %%
test["result_list"]

# %%
def price_node(state: AnalyzerState):
    # 1. State로 부터 필요한 정보 가져오기
    review = state.get("review") or ""
    aspect = state.get("aspect") or []
    label = state.get("label") or []
    result = state.get("result_list") or[]

    # 2. 프롬프트 구성
    sys_msg = '''
너는 제품의 '가격 경쟁력 및 경제적 가치' 개선을 담당하는 가격 전략 전문가(price_llm)야.
입력된 [aspect], [label] 데이터와 [review] 원문을 함께 분석하여, 네가 담당하는 속성 중 불만족(0)으로 평가된 항목에 대한 구체적인 원인 분석과 맞춤형 해결 방안을 제시해.

[담당 속성 영역]
가격, 할인, 가성비, 구성

[분석 및 해결 지침]
1. 타겟 추출: [aspect]와 [label] 리스트는 같은 인덱스로 1:1 매칭되어 있어. [label] 값이 0(불만족)인 항목 중, 너의 [담당 속성 영역]에 해당하는 단어만 필터링해.
2. 리뷰 문맥 파악: 필터링된 속성들이 [review] 원문에서 구체적으로 어떻게 묘사되었는지 파악해 (예: 단순히 '가격' 불만이 아니라 "용량 대비 가격이 너무 비싸다"거나 "할인율이 낮다" 등 사용자의 실제 경험 확인).
3. 맞춤 해결책 제시: 리뷰 원문에서 파악한 정확한 불만 원인을 바탕으로, 마케팅 및 영업 기획자 관점에서 구체적이고 실현 가능한 개선 방안을 도출해.
4. 영역 제한: 너의 담당 속성이 아닌 불만족 항목(예: 보습, 발색, 배송 등)은 철저히 무시하고 언급하지 마.

[출력 형식]
반드시 아래의 텍스트(문자열) 형식으로만 응답해. JSON이나 마크다운 코드 블록은 절대 사용하지 마. 부가적인 인사말이나 설명도 금지해.

[개선 대상 속성]: 불만족으로 확인된 너의 담당 속성들을 쉼표로 구분하여 나열 (예: 가격, 구성)

- 속성: 불만족 속성 이름 1
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 프로모션 기획, 용량 리뉴얼, 결합 상품 구성 변경 등 마케팅 관점의 실질적인 해결 방안

- 속성: 불만족 속성 이름 2
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 프로모션 기획, 용량 리뉴얼, 결합 상품 구성 변경 등 마케팅 관점의 실질적인 해결 방안
    '''
    user_msg = f'''
    [review]
    {review}

    [aspect]
    {aspect}

    [label]
    {label}
    '''
    # 3. llm 호출
    response = price_llm.invoke([
        SystemMessage(content=sys_msg),
        HumanMessage(content=user_msg)
    ])

    result.append(response.content)
    # 4. State 업데이트
    return {

      "messages": [response],

      "result_list": [response.content]

    }

# %%
test = price_node(test)

# %%
test = {
    "review": '홈쇼핑 광고에서도 정말 많이 하고 많은 분들이 궁금해하셨던 바로 그 제품 사용 후기 가져왔습니다. 저도 구매를 직접 해서 써 봤는데 좋은 점이 없는 것 같아서 알려드리고 싶었어요... 단점이 너무 많은 제품이라.. 무슨 말부터 시작을 해야 될 지 모르겠습니다. 일단 이 제품을 사게 된 계기는 홈쇼핑 광고를 보고 샀어요. 구성이 너무 좋아서 구매를 했습니다. 배송은 빨리 왔고 오자 마자 기대를 가지고 사용하게 되었어요. 하지만 하는 내내 풍기는 이상한 냄새에 머리가 아팠습니다. 두피에 자극도 있어서 지금 너무 가려운 것 같습니다...ㅠㅠ 약을 먹어도 가려움이 없어지지 않네요. 염색제 색상도 마음에 들지 않았고 발색도 너무 어둡게 나온 것 같습니다. 결론은 저는 추천하고 싶지 않은 제품이네요~ 다른 염색약 사용하시는 것이 더 좋을 것 같다는 게 제 결론입니다..!!',
    "aspect": ["보습", "가격", "향"],
    "label": [0, 0, 0],
    "next_node": [],
    "result": ["[개선 대상 속성]: 보습\n\n- 속성: 보습\n- 원인 분석: 리뷰에서 제품 사용 후 두피 자극과 가려움이 발생했으며, 이는 제품이 두피 보습에 충분하지 못하거나 자극적인 성분이 포함되어 있을 가능성을 시사함.\n- 개선 방안: 두피 자극을 완화하고 보습을 강화하기 위해 히알루론산, 판테놀 등 보습 및 진정 성분을 추가하거나 함량을 높이고, 알코올이나 향료 등 자극 가능성이 있는 성분을 저감 또는 대체하는 방향으로 성분 조정을 권장함. 또한, pH 밸런스를 두피 친화적으로 맞추어 자극을 최소화하는 포뮬러 개선이 필요함."]
}

# %%
test["result_list"]

# %%
def texture_node(state: AnalyzerState):
    # 1. State로 부터 필요한 정보 가져오기
    review = state.get("review") or ""
    aspect = state.get("aspect") or []
    label = state.get("label") or []
    result = state.get("result_list") or[]

    # 2. 프롬프트 구성
    sys_msg = '''
너는 제품의 '제형, 사용감, 피부 자극 및 향기' 개선을 담당하는 제형 개발 전문가(Texture_llm)야.
입력된 [aspect], [label] 데이터와 [review] 원문을 함께 분석하여, 네가 담당하는 속성 중 불만족(0)으로 평가된 항목에 대한 구체적인 원인 분석과 맞춤형 해결 방안을 제시해.

[담당 속성 영역]
발림성, 흡수력, 사용감, 제형 밀도, 제형, 유분감, 밀착력, 번짐, 자극, 향

[분석 및 해결 지침]
1. 타겟 추출: [aspect]와 [label] 리스트는 같은 인덱스로 1:1 매칭되어 있어. [label] 값이 0(불만족)인 항목 중, 너의 [담당 속성 영역]에 해당하는 단어만 필터링해.
2. 리뷰 문맥 파악: 필터링된 속성들이 [review] 원문에서 구체적으로 어떻게 묘사되었는지 파악해 (예: 단순히 '자극' 불만이 아니라 "바르자마자 따갑고 가렵다"거나, '향'에 대해 "인공적인 냄새가 강하다" 등 사용자의 실제 경험 확인).
3. 맞춤 해결책 제시: 리뷰 원문에서 파악한 정확한 불만 원인을 바탕으로, 제형 연구원 및 향료 전문가 관점에서 구체적이고 실현 가능한 개선 방안을 도출해.
4. 영역 제한: 너의 담당 속성이 아닌 불만족 항목(예: 보습, 발색, 가격, 배송 등)은 철저히 무시하고 언급하지 마.

[출력 형식]
반드시 아래의 텍스트(문자열) 형식으로만 응답해. JSON이나 마크다운 코드 블록은 절대 사용하지 마. 부가적인 인사말이나 설명도 금지해.

[개선 대상 속성]: 불만족으로 확인된 너의 담당 속성들을 쉼표로 구분하여 나열 (예: 자극, 향)

- 속성: 불만족 속성 이름 1
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 점증제 변경, 알러지 유발 성분 배제, 가식제 조절, 향료 배합 변경 등 연구원 관점의 실질적이고 전문적인 개선 방안

- 속성: 불만족 속성 이름 2
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 점증제 변경, 알러지 유발 성분 배제, 가식제 조절, 향료 배합 변경 등 연구원 관점의 실질적이고 전문적인 개선 방안
    '''
    user_msg = f'''
    [review]
    {review}

    [aspect]
    {aspect}

    [label]
    {label}
    '''
    # 3. llm 호출
    response = price_llm.invoke([
        SystemMessage(content=sys_msg),
        HumanMessage(content=user_msg)
    ])

    result.append(response.content)
    # 4. State 업데이트
    return {

      "messages": [response],

      "result_list": [response.content]

    }

# %%
def design_node(state: AnalyzerState):
    # 1. State로 부터 필요한 정보 가져오기
    review = state.get("review") or ""
    aspect = state.get("aspect") or []
    label = state.get("label") or []
    result = state.get("result_list") or[]

    # 2. 프롬프트 구성
    sys_msg = '''
너는 제품의 '외형 디자인, 패키징 및 사용 편의성' 개선을 담당하는 제품 디자이너(Design_llm)야.
입력된 [aspect], [label] 데이터와 [review] 원문을 함께 분석하여, 네가 담당하는 속성 중 불만족(0)으로 평가된 항목에 대한 구체적인 원인 분석과 맞춤형 해결 방안을 제시해.

[담당 속성 영역]
디자인, 색감(색상), 사이즈(크기), 휴대성, 편의성, 위생, 포장

[분석 및 해결 지침]
1. 타겟 추출: [aspect]와 [label] 리스트는 같은 인덱스로 1:1 매칭되어 있어. [label] 값이 0(불만족)인 항목 중, 너의 [담당 속성 영역]에 해당하는 단어만 필터링해.
2. 리뷰 문맥 파악: 필터링된 속성들이 [review] 원문에서 구체적으로 어떻게 묘사되었는지 파악해 (예: 단순히 '포장' 불만이 아니라 "용기가 잘 깨진다"거나, '색상'에 대해 "상세 페이지와 실제 색감이 다르다" 등 사용자의 실제 경험 확인).
3. 맞춤 해결책 제시: 리뷰 원문에서 파악한 정확한 불만 원인을 바탕으로, 제품 디자이너 및 패키징 전문가 관점에서 구체적이고 실현 가능한 개선 방안을 도출해.
4. 영역 제한: 너의 담당 속성이 아닌 불만족 항목(예: 보습, 가격, 배송 등)은 철저히 무시하고 언급하지 마.

[출력 형식]
반드시 아래의 텍스트(문자열) 형식으로만 응답해. JSON이나 마크다운 코드 블록은 절대 사용하지 마. 부가적인 인사말이나 설명도 금지해.

[개선 대상 속성]: 불만족으로 확인된 너의 담당 속성들을 쉼표로 구분하여 나열 (예: 디자인, 포장)

- 속성: 불만족 속성 이름 1
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 용기 구조 변경, 색상 라인업 수정, 패키지 내구성 보강 등 디자이너 관점의 실질적인 해결 방안

- 속성: 불만족 속성 이름 2
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 용기 구조 변경, 색상 라인업 수정, 패키지 내구성 보강 등 디자이너 관점의 실질적인 해결 방안
    '''
    user_msg = f'''
    [review]
    {review}

    [aspect]
    {aspect}

    [label]
    {label}
    '''
    # 3. llm 호출
    response = price_llm.invoke([
        SystemMessage(content=sys_msg),
        HumanMessage(content=user_msg)
    ])

    return {

      "messages": [response],

      "result_list": [response.content]

    }

# %%
def service_node(state: AnalyzerState):
    # 1. State로 부터 필요한 정보 가져오기.
    review = state.get("review") or ""
    aspect = state.get("aspect") or []
    label = state.get("label") or []
    result = state.get("result_list") or[]

    # 2. 프롬프트 구성
    sys_msg = '''
너는 제품의 '배송 서비스 및 고객 경험 관리'를 담당하는 CS 전략 전문가(Service_llm)야.
입력된 [aspect], [label] 데이터와 [review] 원문을 함께 분석하여, 네가 담당하는 속성 중 불만족(0)으로 평가된 항목에 대한 구체적인 원인 분석과 맞춤형 해결 방안을 제시해.

[담당 속성 영역]
배송, 만족도, 재구매, 피부타입

[분석 및 해결 지침]
1. 타겟 추출: [aspect]와 [label] 리스트는 같은 인덱스로 1:1 매칭되어 있어. [label] 값이 0(불만족)인 항목 중, 너의 [담당 속성 영역]에 해당하는 단어만 필터링해.
2. 리뷰 문맥 파악: 필터링된 속성들이 [review] 원문에서 구체적으로 어떻게 묘사되었는지 파악해 (예: 단순히 '배송' 불만이 아니라 "배송이 너무 느리다"거나, '피부타입'에 대해 "건성 피부에는 너무 매트하다" 등 사용자의 실제 경험 확인).
3. 맞춤 해결책 제시: 리뷰 원문에서 파악한 정확한 불만 원인을 바탕으로, 고객 서비스 및 브랜드 매니저 관점에서 구체적이고 실현 가능한 개선 방안을 도출해.
4. 영역 제한: 너의 담당 속성이 아닌 불만족 항목(예: 보습, 자극, 가격 등)은 철저히 무시하고 언급하지 마.

[출력 형식]
반드시 아래의 텍스트(문자열) 형식으로만 응답해. JSON이나 마크다운 코드 블록은 절대 사용하지 마. 부가적인 인사말이나 설명도 금지해.

[개선 대상 속성]: 불만족으로 확인된 너의 담당 속성들을 쉼표로 구분하여 나열 (예: 배송, 피부타입)

- 속성: 불만족 속성 이름 1
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 배송 프로세스 점검, 피부타입별 가이드라인 세분화, 보상 정책 수립 등 CS 관점의 실질적인 해결 방안

- 속성: 불만족 속성 이름 2
- 원인 분석: 리뷰 원문을 기반으로 해당 속성에 불만을 느낀 구체적인 이유 요약
- 개선 방안: 배송 프로세스 점검, 피부타입별 가이드라인 세분화, 보상 정책 수립 등 CS 관점의 실질적인 해결 방안
    '''
    user_msg = f'''
    [review]
    {review}

    [aspect]
    {aspect}

    [label]
    {label}
    '''
    # 3. llm 호출
    response = price_llm.invoke([
        SystemMessage(content=sys_msg),
        HumanMessage(content=user_msg)
    ])

    return {

      "messages": [response],

      "result_list": [response.content]

    }

# %%
from langgraph.types import Send

def route_to_experts(state: AnalyzerState):
    """
    router_node에서 결정된 next_node 리스트를 바탕으로
    각 전문가 노드(performance, price 등)에 병렬로 작업을 전달합니다.
    """
    sends = []

    # router_node에서 저장한 차기 노드 리스트를 가져옵니다.
    next_nodes = state.get("next_node") or []

    # 전문가 노드에게 전달할 공통 데이터 (리뷰 원문, 속성, 라벨)
    # 각 전문가 노드는 이 데이터를 바탕으로 자신의 담당 영역을 분석합니다.
    payload = {
        "review": state.get("review"),
        "aspect": state.get("aspect"),
        "label": state.get("label")
    }

    for node_name in next_nodes:
        # 리스트에 담긴 이름이 실제 builder에 등록된 노드 이름과 일치하는지 확인하며 Send 생성
        if node_name in ["performance_node", "price_node", "texture_node", "design_node", "service_node"]:
            print(f"--- [Routing] {node_name}으로 작업을 전달합니다. ---")
            sends.append(Send(node_name, payload))
        else:
            # 리스트에 예상치 못한 이름이 있거나 비어있을 경우 안전장치
            print(f"--- [Routing] 알 수 없는 노드({node_name}), 기본 서비스 노드로 전달합니다. ---")
            sends.append(Send("service_node", payload))

    # 만약 next_node가 완전히 비어있다면 기본 서비스 노드로 전달
    if not sends:
        sends.append(Send("service_node", payload))

    return sends

# %%
def aggregator_node(state: AnalyzerState):
    """
    여러 전문가 에이전트로부터 전달받은 분석 결과(result_list)를
    하나의 통합 메시지로 취합합니다.
    """
    print("--- [Aggregator] 모든 전문가의 의견을 통합 중... ---")
    results = state.get("result_list") or []
    print(f"수집된 결과 개수: {len(results)}개")

    if not results:
        final_answer = "분석 결과가 없습니다. 모든 항목에 만족하셨거나 처리 중 오류가 발생했습니다."
    else:
        combined_results = "\n\n" + "="*30 + "\n\n".join(results)

        final_answer = f"""
[종합 제품 개선 제안서]

고객님의 리뷰를 바탕으로 각 분야 전문가들이 분석한 개선 방안입니다.
{combined_results}

---
위 개선 방안이 제품 품질 향상에 도움이 되기를 바랍니다.
"""

    return {"final_result": final_answer}

# %%
builder = StateGraph(AnalyzerState)

builder.add_node("router_node", router_node)
builder.add_node("performance_node", performance_node)
builder.add_node("price_node", price_node)
builder.add_node("texture_node", texture_node)
builder.add_node("design_node", design_node)
builder.add_node("service_node", service_node)
builder.add_node("aggregator_node", aggregator_node)

builder.add_edge(START, "router_node")

builder.add_conditional_edges("router_node", route_to_experts,
                ["performance_node", "price_node", "texture_node", "design_node", "service_node"],
)

builder.add_edge("performance_node", "aggregator_node")
builder.add_edge("price_node", "aggregator_node")
builder.add_edge("texture_node", "aggregator_node")
builder.add_edge("design_node", "aggregator_node")
builder.add_edge("service_node", "aggregator_node")

builder.add_edge("aggregator_node", END)

graph = builder.compile()

# %%
graph

# %%
test = {
    "review": '홈쇼핑 광고에서도 정말 많이 하고 많은 분들이 궁금해하셨던 바로 그 제품 사용 후기 가져왔습니다. 저도 구매를 직접 해서 써 봤는데 좋은 점이 없는 것 같아서 알려드리고 싶었어요... 단점이 너무 많은 제품이라.. 무슨 말부터 시작을 해야 될 지 모르겠습니다. 일단 이 제품을 사게 된 계기는 홈쇼핑 광고를 보고 샀어요. 구성이 너무 좋아서 구매를 했습니다. 배송은 빨리 왔고 오자 마자 기대를 가지고 사용하게 되었어요. 하지만 하는 내내 풍기는 이상한 냄새에 머리가 아팠습니다. 두피에 자극도 있어서 지금 너무 가려운 것 같습니다...ㅠㅠ 약을 먹어도 가려움이 없어지지 않네요. 염색제 색상도 마음에 들지 않았고 발색도 너무 어둡게 나온 것 같습니다. 결론은 저는 추천하고 싶지 않은 제품이네요~ 다른 염색약 사용하시는 것이 더 좋을 것 같다는 게 제 결론입니다..!!',
    "aspect": ["보습", "가격", "향"],
    "label": [0, 0, 0],
    "next_node": [],
    "result_list": [],
    "final_result": ""
}

# %%
result = graph.invoke(test)
# Out:
# --- [Router] 의도 분류 중... ---
# --- [Routing] performance_node으로 작업을 전달합니다. ---
# --- [Routing] price_node으로 작업을 전달합니다. ---
# --- [Routing] texture_node으로 작업을 전달합니다. ---
# --- [Aggregator] 모든 전문가의 의견을 통합 중... ---
# 수집된 결과 개수: 3개

# %%
print(result["final_result"])
# Out:
# [종합 제품 개선 제안서]
#
# 고객님의 리뷰를 바탕으로 각 분야 전문가들이 분석한 개선 방안입니다.
#
#
# ==============================[개선 대상 속성]: 보습
#
# - 속성: 보습
# - 원인 분석: 리뷰에서 제품 사용 후 두피 자극과 가려움이 발생했으며, 이는 보습 부족으로 인한 두피 건조와 자극 가능성을 시사함.
# - 개선 방안: 두피 보습을 강화하기 위해 히알루론산, 판테놀, 세라마이드 등의 보습 성분을 추가하거나 함량을 높이고, 자극을 줄이기 위해 저자극성 보습 포뮬러로 개선할 것. 또한, 두피 진정 효과가 있는 알로에 베라 추출물이나 카모마일 추출물 등을 배합하여 가려움 완화에 도움을 줄 수 있도록 한다.
#
# [개선 대상 속성]: 가격
#
# - 속성: 가격
# - 원인 분석: 구매 결정에 영향을 준 '구성'은 긍정적으로 평가되었으나, 가격에 대한 불만족은 제품 사용 후 품질 대비 비용이 높다는 인식에서 비롯된 것으로 보임. 사용하면서 발생한 여러 부정적인 경험으로 인해 가격 대비 만족도가 매우 낮아 가격적 가치가 부족하다고 판단됨.
# - 개선 방안: 제품의 품질 문제 해결과 병행하여, 초기 진입장벽을 낮추기 위한 할인 프로모션이나 체험용 소용량 패키지 출시를 검토할 것. 또한, 구성품의 가성비를 강화하기 위해 세트 구성 변경이나 추가 혜택(예: 사은품, 재구매 할인)을 통해 가격 경쟁력을 높이는 전략을 추진할 필요가 있음.
#
# [개선 대상 속성]: 자극, 향
#
# - 속성: 자극
# - 원인 분석: 사용자가 두피에 제품을 사용한 후 심한 가려움과 자극을 경험하였으며, 증상이 약 복용 후에도 지속되어 불편함이 매우 큼.
# - 개선 방안: 자극을 유발할 수 있는 알레르기 유발 성분(예: 파라페닐렌디아민, 암모니아 등)의 함량을 줄이거나 대체 가능한 저자극성 성분으로 교체하고, 보습과 진정 효과가 있는 성분(예: 판테놀, 알란토인, 센텔라 아시아티카 추출물) 첨가를 통해 두피 자극을 완화하는 방향으로 제형 개선을 진행할 것.
#
# - 속성: 향
# - 원인 분석: 제품 사용 중 머리가 아플 정도로 강하고 이상한 인공적인 냄새가 지속되어 사용에 큰 불편을 겪음.
# - 개선 방안: 강하고 자극적인 합성 향료 사용을 최소화하고 천연 유래 향료나 저자극성 향료로 대체하여 냄새를 부드럽고 쾌적하게 조정할 것. 또한, 냄새를 중화할 수 있는 탈취 성분을 첨가하여 사용 시 불쾌감을 줄이는 방향으로 향기 프로파일을 재설계할 필요가 있음.
#
# ---
# 위 개선 방안이 제품 품질 향상에 도움이 되기를 바랍니다.

# %%
# 코랩에 파일 업로드
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_csv("data.csv")
reviews = df["review"].tolist()

# %%
def clear_all_data():
    conn = sqlite3.connect("user_review_db.db")
    cursor = conn.cursor()

    cursor.execute("DELETE FROM user_reviews")

    conn.commit()
    conn.close()

def init_db():
  conn = sqlite3.connect("user_review_db.db")
  cursor = conn.cursor()

  cursor.execute("""
CREATE TABLE IF NOT EXISTS user_reviews (
    id INTEGER PRIMARY KEY,
    review TEXT,
    aspect TEXT,
    label TEXT,
    score INTEGER,
    updated_at DATETIME DEFAULT CURRENT_TIMESTAMP
)
""")

  conn.commit()
  conn.close()

def insert_review_data_db(review_list):
  conn = sqlite3.connect("user_review_db.db")
  cursor = conn.cursor()

  for review in review_list:
    cursor.execute(
        "INSERT INTO user_reviews (review) VALUES (?)", (review, )
    )
  conn.commit()
  conn.close()

# %% [markdown]
# 리뷰를 읽어서 Agent 실행후 결과 저장**

# %%
import asyncio

# 1) 미처리 리뷰 조회 함수
def select_None_analyze():
  conn = sqlite3.connect("user_review_db.db")
  cursor = conn.cursor()
  cursor.execute("SELECT review FROM user_reviews WHERE aspect IS NULL")
  rows = cursor.fetchall()
  conn.close()

  clean_reviews = [row[0] for row in rows]
  return clean_reviews


# 2) Agent 결과에서 aspect, label 추출 함수 (동기)
def extract_review_elements(clean_reviews):
  result = []
  for review in clean_reviews:
    print("-리뷰 분석 시작합니다.-")
    initial_state = {
                "input_review": review,
                "score": 0,
                "aspect_list": ["보습", "가격", "향", "포장"],
                "max_num": 3,
                "current_num": 0,
                "messages": []
    }

    final_state = app.invoke(initial_state)
    print("-분석 완료-")
    result.append({
        "aspect": final_state["result"]["aspect"],
        "label": final_state["result"]["label"],
        "score": final_state["result"]["score"]})
  return result


# 2-1) Agent 결과에서 aspect, label 추출 함수 (비동기)
async def extract_review_elements_async(clean_reviews, concurrency=5):
    semaphore = asyncio.Semaphore(concurrency)

    async def analyze_one(review):
        async with semaphore:
            print(f"-리뷰 분석 시작: {review[:20]}...-")
            initial_state = {
                "input_review": review,
                "score": 0,
                "aspect_list": ["보습", "가격", "향", "포장"],
                "max_num": 3,
                "current_num": 0,
                "messages": []
            }

            final_state = await app.ainvoke(initial_state)
            print("-분석 완료-")
            return {
                "aspect": final_state["result"]["aspect"],
                "label": final_state["result"]["label"],
                "score": final_state["result"]["score"],
            }

    results = await asyncio.gather(*[analyze_one(r) for r in clean_reviews])
    return results


# 3) DB 업데이트
def update_db(clean_reviews, result):
  conn = sqlite3.connect("user_review_db.db")
  cursor = conn.cursor()

  for i in range (len(result)):
    aspect = result[i]["aspect"]
    label = result[i]["label"]
    score = result[i]["score"]
    review_text = clean_reviews[i].strip()

    cursor.execute(
        "UPDATE user_reviews SET aspect = ?, label = ?, score = ? WHERE review = ?",
        (
              json.dumps(aspect, ensure_ascii=False),
              json.dumps(label),
              score,
              review_text
          )
    )

  conn.commit()
  conn.close()


# 4) batch 실행 (동기)
def start_batch():
  init_db()
  clear_all_data()
  insert_review_data_db(reviews)
  None_analyze_reviews = select_None_analyze()
  if len(None_analyze_reviews) == 0:

    print("-분석할 리뷰가 없습니다.-")
  else:
    print(f"-분석할 리뷰{len(None_analyze_reviews)}개 감지됐습니다-\n-분석을 시작합니다.-")
    analyzed_results = extract_review_elements(None_analyze_reviews)
    print("-분석이 완료됐습니다.-\n-Update를 실행합니다-")
    update_db(None_analyze_reviews, analyzed_results)
    print("-Update가 완료됐습니다.-")


# 4-1) batch 실행 (비동기)
async def start_batch_async():
    init_db()
    clear_all_data()
    insert_review_data_db(reviews)
    None_analyze_reviews = select_None_analyze()
    if len(None_analyze_reviews) == 0:
        print("-분석할 리뷰가 없습니다.-")
        return
    print(f"-분석할 리뷰 {len(None_analyze_reviews)}개 감지됐습니다-\n-분석을 시작합니다.-")
    analyzed_results = await extract_review_elements_async(None_analyze_reviews, 6)   # 일꾼을 줄이거나 늘리고 싶으면 6을 조정하면 됨.
    print("-분석이 완료됐습니다.-\n-Update를 실행합니다-")
    update_db(None_analyze_reviews, analyzed_results)
    print("-Update가 완료됐습니다.-")

# %%
# 배치 실행 (비동기 버전)
await start_batch_async()

# 실행 결과 확인
conn = sqlite3.connect("user_review_db.db")
cursor = conn.cursor()
cursor.execute("SELECT * FROM user_reviews")
rows = cursor.fetchall()
for row in rows:
    print(row)
conn.close()

# %%
await start_batch_async()

# %%
import time

# 동기 실행
t1 = time.time()
start_batch()
sync_time = time.time() - t1

# 비동기 실행 (데이터 다시 초기화됨)
t2 = time.time()
await start_batch_async()
async_time = time.time() - t2

print(f"\n⏱️ 동기:   {sync_time:.2f}초")
print(f"⏱️ 비동기: {async_time:.2f}초")
print(f"🚀 {sync_time / async_time:.1f}배 빨라짐")

# %%
start_batch()

# %%
conn = sqlite3.connect("user_review_db.db")
cursor = conn.cursor()
cursor.execute("SELECT * FROM user_reviews")
rows = cursor.fetchall()
for row in rows:
    print(row)
conn.close()
# Out:
# (1, '연령상관없이 요즘 너무 인기 있어서 한번 사봤습니다. 도대체 얼마나 좋길래 다들 OO OO 하는지 써보겠습니다. 다만 가격이 비싸서 아쉽고 구성도 더 알찼으면 좋았을 거 같아요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 3, '2026-05-13 02:23:59')
# (2, '구매후 3일정도 사용하고 후기 작성하는데요. 최근 들어 탈모가 심해지는것 같아서 탈모샴푸를 알아보게 됐어요. 그동안 그냥 일반샴푸만 사용하다가 탈모샴푸를 처음 써봐서 다른 제품과의 비교는 할 수 없지만 나름대로 느낌점을 써보는데요. 제형이 밀도가 높다는 느낌이 들었어요. 그리고 은은한 민트향이 너무 좋았네요. 앞으로 꾸준히 사용해봐야 효과를 볼 수 있겠지만 짧게나마 느낀점 작성해봅니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 3, '2026-05-13 02:23:59')
# (3, '친구랑 같이 기숙사에 사는데 어느 날 친구가 이 향수를 사 왔더라구요?? 향이 어떨지 하고 저도 뿌려봤는데 향이 너무 좋아서 사게 되었어요!! 후기 알려 드릴게요~ 일단 저는 향수를 자주 사용하는 편이라 집에 향수가 많지만 그래도 구매를 하게 되었습니다! 향이 안 좋은 것도 많이 사서 실패도 많이 해서 그런지 이번에는 잘 구매한 것 같습니다!! 일단 이 제품은 향이 강하지 않아서 좋았어요~ 약간 은은하게 남성다운 향이 나서 좋았던 것 같습니다~ 지속력은 생각보다 길지 않아서 자주 뿌리게 되긴 하네요! 그래도 뿌릴 때 마다 기분이 좋아요! 향이 좋거든요 ㅋㅋㅋㅋ 그리고 직접 사시면 아시겠지만 이거 디자인이 아주 물건입니다!! 디자인이 완전 고급스러워 보여요 한 달 정도 사용했는데 너무 좋네요!! 당분간은 이 향수만 쭉 쓸 것 같아요!! 추천 합니다^^', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 1]', 5, '2026-05-13 02:23:59')
# (4, '써보고 주위 선물 하려고 샀어요. 눈 주위에 바르고 있는데 덜 건조하고 촉촉해요 휴대하기도 편해서 좋아요', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (5, '택배 잘 받았어요. 처음으로 주문해서 써봤는데 발림성이 부드러워서 좋고 용량이 많아서 오래 쓸 것 같아요. 할인해서 저렴하게 구입했어요. 케이스도 고급스럽고 이쁘네요. 사은품이 없어 아쉽지만 다음에 다른 제품도 써 볼까 합니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 1]', 4, '2026-05-13 02:23:59')
# (6, '꼭 써보고 싶었던 제품 드디어 구매했어요.커버력은 기본 광채나는 피부 표현을 원한다면 케이스까지 고급스러운 이제품 강추입니다', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 1]', 4, '2026-05-13 02:23:59')
# (7, '다른 회사 제품만 쓰다가 처음 써봤습니다. 세팅력도 좋고 향도 괜찮습니다. 배송 빨랐고 무엇보다 샴푸 사은품도 좋았습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (8, '좋은 가격에 잘 구매했네요. 발색도 괜찮고 샴푸 린스 구성까지 마음에 들어서 재구매했습니다. 염색은 집에서 잘 안 했는데 쟁여두고 집에서 하려고 샀어요. OOO 구매 추천합니다.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (9, '어느새 코로나가 일상이 되어버렸습니다.. 그래서 주위 사람들이 정말 많이 걸렸는데.. 저는 무서워서 이 손 소독제만 사용하고 있어요!! 손 소독이 정말 잘 되어서 추천 드리고 싶네요~ 다른 손 소독제는 향도 안 좋고 바르면 손이 끈적거려 안 좋았는데 이 제품은 향도 좋고 흡수가 빨라 손이 끈적거리지 않습니다!! 게다가 용량도 많아서 듬뿍 오래 사용할 수 있는 것 같아요!! 청량감도 느껴져서 손 소독할 때 시원해서 좋네요~ 유통기한도 길어서 오래 사용할 수 있어 좋은 것 같습니다!! 가격도 저렴하니 얼른 구매하세요!! 인기 제품이라 품절도 그만큼 빨리 되니 품절 되기 전에 구매하시면 좋을 것 같습니다 :)', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 0]', 5, '2026-05-13 02:23:59')
# (10, '파우더 많이 구매해봤지만 역시 ㅇㅇㅇ 제품이 좋은거 같아요. 향도 은은하고 보습력도 좋습니다. 만족해요.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (11, '사이즈가 조금 커서 잘라쓰는 부분이 있는데 대체적으로 디자인이 이뻐서 만족해요. 잘 쓸께요.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (12, '제품 좋은 것은 다 아실 거 같아요. 유효기간이 2025년 11월 3일로 길어서 좋습니다. 사은품까지 주셔서 좋았어요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (13, '향 맘에 듭니다. 첫 향때문에 호불호가 갈릴수 있을거 같긴 한데 이제 저는 그 첫 향마저도 좋아요. 늦은 가을 겨울에 쓰기 딱입니다.', '["향"]', '[1]', 4, '2026-05-13 02:23:59')
# (14, '남자친구가 제일 좋아하는 향수라고 해서 샀어요. 향이 은은하고 좋습니다. 지속력은 살짝 아쉬워요. 다음에도 사러 올게요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (15, '이 브랜드 다들 아시잖아요. 바디 스프레이 쓰다가 향수도 구매했어요. 너무 마음에 듭니다. 여름에 사용하기 좋을 것 같습니다. 향이 강해서 좋고 지속력도 좋아서 이 제품 구매 추천 드려요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (16, '발림성도 좋아요. 손등에 살짝 바르고 잠시 후에 손으로 문질렀는데 잘 번지지 않아요. 용량이 작아서 빨리 없어지네요. 재구매할 것 같긴해요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (17, '딸이 사용해요 향이 좋고 머릿결도 부드럽고 걍 좋다고 하네요 사실 탈모예방샴푸는 아니어서 두피에는 탈모예방 샴푸를 따로 사용하고 있답니다', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (18, '아이들도 같이 쓸 수 있어서 좋고 거기다 아빠 엄마도 슥슥 바릅니다 발림성이 좋고 향도 없어서 좋구요 저희 가족한테 잘 맞는 것 같아요 한겨울 초건조할때도 사계절용으로 만족하며 쓰고 있습니다', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (19, '입점 기념으로 좋은 가격에 포인트까지 써서 더 저렴히 잘 구매했네요. 용량도 많지 않고 적당하고 향도 상큼하니 좋아요~', '["가격", "향"]', '[1, 1]', 5, '2026-05-13 02:23:59')
# (20, '항상 사용하는 제품이라 믿고 구매했습니다. 유통기한도 넉넉하고 무엇보다 할인 행사중이라 오프라인보다 더 저렴하게 구매해서 만족해요. 많이 파시길 바랍니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (21, '일단 향은 없고 동영상 속에서는 좀 많이 짜서 바로 안스며드는것처럼 나왔는데 잘 스며들고 촉촉하고 좋습니다. 제가 손에 습진이 엄청 심한데 이거 계속 바르니 부드러워지고 좋습니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (22, '땀이 많이 나서 냄새가 신경쓰여서 구매했습니다. 이 제품은 산뜻하면서도 가벼워요. 손에 묻어나지 않고 잘 발리고 땀 냄새 제거에도 효과가 좋아요. 부담없이 쓰기 좋은 제품입니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (23, 'C밤사용해보구 편하고 피부도 밝아진거 같아 멀티밤도 구매해봅니다. 가격도 좋고 효과기대되네요. 감사합니다', '["보습", "가격"]', '[1, 1]', 4, '2026-05-13 02:23:59')
# (24, '마스크도좋지만 사은품으로온 크림도 수면팩으로 사용했더니 촉촉하게좋습니다', '["보습"]', '[1]', 5, '2026-05-13 02:23:59')
# (25, '안녕하세요~ 저의 최애템이 될 것 같은 ㅇㅇㅇ ㅇㅇ 쿠션 파운데이션을 들고 와봤어용~ 사실 전에 ㅇㅇㅇ에서 다른 파운데이션을 샀다가 크게 실망을 했었는데… 이 쿠션은 평이 좋아서 한번 구매해 보았습니다ㅎㅎ 일단 글로우 쿠션이고요~ 바를 때 촉촉하면서도 광이 올라오는 게 피부가 되게 좋아보이더라구요ㅎㅎ 촉촉한데 지속력도 꽤 높은 편이에요! 그런데 커버력이 많이 높은 편은 아니라 이런 점 참고해 주세요! 저는 여러모로 매우 만족하면서 사용 중인 제품이네요ㅎㅎ', '[]', '[]', 5, '2026-05-13 02:23:59')
# (26, '여름 필수품이고 타 제품은 이상하게 가려울 때도 있는데 OOO는 가려움도 없고 겨드랑이가 뽀송하게 지속되어 만족합니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (27, '직장인분들 어떤 향수 쓰실지 고민이 참 많으시죠? 너무 과한 향을 뿌리고 가면 직원 눈치 보이고... 그렇다고 너무 은은하면 티도 안나고... 그럴때 저는 이 향수 과감하게 추천 드리고 싶어요!!! 저는 30대 직장인입니다!! 직장 생활 하시면 공감 가시겠지만 오랫동안 회사에 있기에.. 향수를 뿌리고 가는 게 좋습니다!! 어떤 향수를 뿌려야 될 지.. 고민이 많으실 거에요~ 이 향수는 향이 엄청 묵직하지 않고 가볍게 은은해서 좋은 것 같아요! 그렇다고 지속력이 짧은 것도 아니라~ 향수 디자인도 고급스럽고 양도 많아서 오래 사용할 수 있어요! 저는 유통기한도 긴 제품이 와서 너무 좋았답니다! 직장인 분들이 사용하시면 딱일 것 같습니다!! 기회가 되신 다면 이 향수 꼭 써보세요~ 저는 주위 직원들이 항상 향이 좋다고 칭찬을 많이 해줍니다~^^', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 1]', 5, '2026-05-13 02:23:59')
# (28, '제형이 부드러운데 끈적임도있고 건조하진않아서 바릅니다 끝부분이 아깝고 바르기불편해오', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 1]', 3, '2026-05-13 02:23:59')
# (29, '시향 못해 봤는데 OOO이 유명한 제품이라 믿고 구입했어요. 향이 고급스럽기 보다는 익숙한 남자 스킨향이 느껴지네요. 무겁고 중후한 향이길 기대했는데 기대한 만큼 아쉬움이 크게 다가오네요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (30, '아침에 머리 감고 저녁 되면 머리카락에 기름기가 올라오는데 이걸로 샴푸하고 나니 기름기가 줄어들어서 괜찮습니다. 향은 좀 진하지만 추천해드립니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (31, '세팅력은 없으나 바르면 머리결이 한결 부드러워져요. 양도 많아서 오래 쓸 것 같아요. 배송은 완전 빠르네요.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (32, '다른 사이트나 일반 매장은 비싸서 구매하기 망설였어요. 그런데 OO쇼핑에서 타사이트보다 가격도 저렴하고 제품도 괜찮은 거 같아서 주문했습니다. 다음에 또 필요하면 재구매할 의사 있습니다. 다만 가격이 좀 더 내려갔으면 좋겠어요.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (33, '살짝 뿌리면 특유의 머스크향 좋습니다. 잔향은 파우더리한 비누향이네요. 그런데 향이 진해서 많이 뿌리면 주변 사람들에게 민폐예요. 겨울에 사용하기 좋은 향수고 달달한 플로랄 계열 향수와 믹스해서 써도 좋습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (34, '홈쇼핑 광고에서도 정말 많이 하고 많은 분들이 궁금해하셨던 바로 그 제품 사용 후기 가져왔습니다. 저도 구매를 직접 해서 써 봤는데 좋은 점이 없는 것 같아서 알려드리고 싶었어요... 단점이 너무 많은 제품이라.. 무슨 말부터 시작을 해야 될 지 모르겠습니다. 일단 이 제품을 사게 된 계기는 홈쇼핑 광고를 보고 샀어요. 구성이 너무 좋아서 구매를 했습니다. 배송은 빨리 왔고 오자 마자 기대를 가지고 사용하게 되었어요. 하지만 하는 내내 풍기는 이상한 냄새에 머리가 아팠습니다. 두피에 자극도 있어서 지금 너무 가려운 것 같습니다...ㅠㅠ 약을 먹어도 가려움이 없어지지 않네요. 염색제 색상도 마음에 들지 않았고 발색도 너무 어둡게 나온 것 같습니다. 결론은 저는 추천하고 싶지 않은 제품이네요~ 다른 염색약 사용하시는 것이 더 좋을 것 같다는 게 제 결론입니다..!!', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 1, '2026-05-13 02:23:59')
# (35, '갖고 싶은 내마음을 알고 남편이 선물해줬어요. 발림이 부드럽고 촉촉하며 향이 좋네요. 예뻐져서 남편에게 자랑해야죠', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (36, '순하고 촉촉해서 머리부터 발끝까지 매일 사용하고 있습니다. 얼굴에 유분기가 조금이라도 과하다 싶으면 뭐가 났었는데 이 제품은 덧발라도 잘 스며들어 좋습니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (37, '아주 맘에 들어요. 한번 발라도 혈색은 좋아 보여요. 주름에 효과가 있는지는 더 써봐야 될 것 같습니다.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (38, '평이 좋아서 구매해 봤어요. 시트 스티커가 넘 강력해서 사용하기 불편하지만 땀 많이 흘리는데 시원하고 좋아요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (39, '눈가가 건조하게 느껴져 OO를 구입했습니다. 상품구성이 좋아 엄마에게도 한개 드렸더니 요즘 엄마친구들도 모두 가지고 다닌다고 엄마도 가지고 싶었다고 너무 좋아하시더라구요. 진작 말씀을 하시지 ...ㅠㅠ 눈가와 목에 부드럽게 촉촉히 발라진다고 좋아하시네요 아침까지 촉촉함이 유지된다고 하시네요. 멀티밤사이즈도 작아서 한개는 가방에 넣어다니며 얼굴 당길때 편하게 바르신다고 하고 한개는 거실에 두고 수시로 바르신다고 합니다. 열심히 바르셔서 다쓰면 또 구입해 드려야 할것 같아요 ^^~', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 1]', 5, '2026-05-13 02:23:59')
# (40, 'ㅇㅇㅇ 크림 항상 구매해서 애용하는 제품이에요. 민감한 피부에도 자극없이 사용하기 좋고 발림성도 좋고 촉촉해서 늘 사용하고 있어요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (41, '처음 사용할땐 청량감이 있었는데 한참 쓰니깐 청량감이 없네요. 그리고 머리카락이 뻣뻣해져서 오일을 발라야 해요', '[]', '[]', 2, '2026-05-13 02:23:59')
# (42, '향도 좋고 사용시 청량감 있습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (43, '걱정했었는데 리뉴얼 전 버전이랑 큰 차이는 없는 것 같습니다. 향이 좀 달라져서 아쉽네요. 제형이 덜 묽은 것 같지만 그래도 잘 발리네요. 배송도 포장도 다 좋았습니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 1]', 4, '2026-05-13 02:23:59')
# (44, '탄력크림은 한방 냄새가 안 나서 좋아요. 피부가 촉촉하면서도 탱탱하게 보여요. 피부톤 까지 밝아 보입니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (45, '색감이 화사하고 발림성이 좋습니다. 묻어나지 않는 건 좋은데 좀 건조한 느낌은 있어요. 잘 안 발려서 붓자국도 나요. 하지만 가볍게 몇 번 두드리면 괜찮아집니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 3, '2026-05-13 02:23:59')
# (46, '가게에서 사용하려고 샀는데 좋은 가격에 충분한 양입니다. 비싼 타사 제품 쓰다가 바꿔 보는데 사용해 보니 상쾌하네요.', '["보습", "가격", "향", "포장"]', '[0, 1, 1, 0]', 4, '2026-05-13 02:23:59')
# (47, '향기도 좋고 상쾌하고 한번도 안 쓴 사람 있어도 한번만 쓴 사람 없는 제품 같네요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (48, '팩이 많이 나오는데 항상 여성용 팩을 사용하다가 남자팩도 있다고 해서 바로 구매해서 써봤습니다 처음 써봤을 때 향이 별로 안 나서 꽤 괜찮은 느낌이 났습니다 그리고 제가 시간을 까먹고 꽤 오랜 시간을 두고 붙여놨는데도 피부가 촉촉 하더라구요~ 제 피부에는 촉촉함이 많으면 되게 과해서 오히려 트러블이 올라올 때도 있는데 이 제품은 남성 전용이라서 그런지 딱 적당한 촉촉함이 있더라구요~~ 남성제품은 살짝 아쉬움이 있을때가 많았었는데 이제 남성전용 제품은 믿고 써볼려고요!!! 재구매 합니다~~', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (49, '애용하는 ㅇㅇㅇ 파우더입니다. 화장 마지막에 항상 사용하는 제품입니다. 그 전의 화장품을 무엇을 사용하던 마지막 마무리로 사용합니다. 마지막에 사용하면 얼굴톤을 밝게 합니다. 끈적임을 사라지게 하고 피부가 환해져서 자신감을 갖게 합니다.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (50, '나이가 들수록 거칠어지고 칙칙해지는 피부에 커버력이 일단 좋은거 같고 다른쿠션을 쓸때는 땀흘리고 다시바르면겉돌았는데 피부에 잘스며들어서 굉장히 좋습니다 아침에 바르고 퇴근할때까지 한두번 두드려주면 퇴근할때도 피부가 화사하네요~^^~', '[]', '[]', 4, '2026-05-13 02:23:59')
# (51, '평소에 뿌리는 헤어에센스를 사용하다가 좀 더 영양을 주려고 오일 제형의 에센스를 한 번 구입해봤어요. 제가 머리숱이 좀 많은 편이다보니 어떤 헤어제품이나 한 번에 많은 용량을 써야하는데 이 제품은 특히 한 번 펌핑에 굉장히 양이 작게 나오네요. 한 번에 10번 이상 펌핑하는 것 같아서 불편해요. 좀 많이 나오면 편할텐데요. 오일치고는 많이 끈적하지 않아서 머리에 바를 때는 좋았어요. 별로 잔여감도 없고 그건 점수를 줄 수 있을 것 같아요. 다만 그냥 바를 때만 좋고 뭔가 발라서 머릿결이 개선이 된다든가 하는건 기대하기 어려울 것같아요. 1+1 세일을 한다면 모를까 정가로 구매하기엔 좀 아까울 것 같아요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 2, '2026-05-13 02:23:59')
# (52, '기존에 쓰던 올인원 제품으로 동일하게 사용할까 하다가 바꾸어 구매해 보았습니다. 큰 차이는 아니지만 보습도 무난하고 사용감이 좋습니다. 기존 제품도 현재 인터넷에 너무 저렴하게 판매하고 있는데 왠지 너무 가격이 저렴한 것도 이상하여 바꾸어 보았어요. 향이 약해서 아쉽습니다. 그래도 가성비는 만족합니다. 2개 구매해서 욕실에 하나씩 두고 사용하고 있습니다. 재구매 의사 있습니다.', '["보습", "가격", "향"]', '[1, 1, 0]', 4, '2026-05-13 02:23:59')
# (53, '상품 품질이 좋아요. 마음에 듭니다. 요즘 건조했는데 바르려고 샀습니다. 넓은 부위에 바르기는 답답하지만 발뒤꿈치나 손에 사용하면 좋습니다. 시중보다 훨씬 싸게 샀습니다. 두고두고 사용합니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (54, '일단 제형은 엄청 뻑뻑하지도 묽지도 않고 보통인데. 복합성피부라 두껍지않게 바르라고해서 가볍게 발라보니 잘 발리네요. 이거 하나 바르고 있었는데도 화장했냐고 물어볼정도로 미백효과도 있습니다. 바른 후 얼굴을 만져보면 겨울철 크림을 엄청많이 바른것처럼 보습도 되었네요. 시카크림이니만큼 피부 트러블에도 진정효과가 있을거라고 생각되네요.', '["보습"]', '[1]', 5, '2026-05-13 02:23:59')
# (55, '홈쇼핑에서 구매 했는데 다른 곳보다 비싼 가격에 양은 적어 금방 쓰게 되네요. 건조한 피부에 촉촉하지 않고 건조한 느낌이 아쉽네요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 1]', 2, '2026-05-13 02:23:59')
# (56, '가격이 비싸요. 뽀송하고 상쾌한데 좀 비쌉니다. 지성피부에는 정말 잘 맞습니다. 리필만 판매하면 좋겠습니다. 아쉬움이 남네요', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 3, '2026-05-13 02:23:59')
# (57, '일반 가게에서 염색약 하나에 만원주고 샀는데 인터넷에서 사니까 저렴하게 한개반 가격에 3개나 샀어요. 새치 염색할때 쓰려고 샀는데 새치커버는 별로 안되네요. 엄마는 사용해보고 좋다고 하시는데 저랑은 안맞는 것 같아요.', '["가격"]', '[1]', 3, '2026-05-13 02:23:59')
# (58, '남편에게 선물했는데 좋다고 합니다. 잔향이 오래가고 그냥 편하게 막뿌리기 좋은거 같습니다. 향이 진한 편이고 지속력도 좋은거 같습니다. 용기도 심플하고 디자인이 고급진 느낌이에요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 1]', 4, '2026-05-13 02:23:59')
# (59, '온가족사용해도 된다는멘트에 아이들로션도 다떨어지고 저도 갑자기 피부가뒤집어져 스트레스받고있던찰라 구매했어요!!어제밤 체험분 바르고 잤는데 아침에 10살딸아이 세수하고 거울보더니 엄마얼굴이왜이리뽀애??그러네요ㅎ망설임없이 본품스킨로션크림다뜯었네요ㅎ스킨로션 향도좋고끈적임없이 산뜻하고좋아요 크림은 번들거려서 낮에살짝만발라야될듯!!밤에 듬뿍바르고자면 아침에 매끈하니 참좋은것같아요', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (60, '처음 사보는데요. 값이 생각보다 비싸네요. 제형이 반죽할 때 좀 덩어리가져서 잘 안풀려요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (61, '상품 품질이 좋네요. OO제품은 믿고 구매합니다. 이번에도 마음에 드네요. 크림 제형이 밀도가 높아서 속까지 촉촉해지는 느낌입니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (62, '한번 써 보았는데 윤기가 나는건 확실하네요 흡수가 다 된건지 금방 없어지기는 했지만요 피부톤을 밝게 해주거나 그러지는 않네요 일단 써보고 효과 좋으면 더 쓰지요', '[]', '[]', 3, '2026-05-13 02:23:59')
# (63, '가격이 비싼편이네요. 처음 바르면 알콜냄새가 살짝 올라와서 별로예요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (64, '트러블이 많은 피부라 예민한 피부인데 친구꺼 써보고 좋아서 바로 구매했네요 사은품 미니 용량도 주시고 밤에는 듬뿍 낮에는 적당히 촉촉하게 발라요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 1]', 5, '2026-05-13 02:23:59')
# (65, '샴푸의 사용감은 정말 최고인 것 같습니다. 모발이 튼튼해지는 느낌이 있어 머리 감는 것에 대한 부담이 많이 적은 것 같고 머리카락 빠지는 정도도 많이 줄어든 것 같아 다음에 다시 재구매 의향 있는 샴푸네요. 샴푸를 사용하고 나면 화장실의 향기도 상큼한 냄새로 가득 차서 기분이 좋은 샴푸네요. 모든 것이 좋고 마음에 드는데 딱 한 가지 더 바람이 있다면 용기가 잘 쓰러져서 자주 짜증이 나곤 하는데 용기의 아랫부분을 더 넓게 해서 다시 만들어 주시면 좋을 것 같습니다. 남편도 사용해보고는 머릿결이 부드러워지고 향이 깔끔한 느낌이 나서 좋다고 하네요. 머리 감을 때 빠지는 머리카락들도 조금 줄어든 것 같습니다. 심지어 머리를 감고 방에 들어가거나 하면 손자들도 하나같이 깨끗한 냄새가 난다며 좋아하네요. 좋은 샴푸를 만들어 소비자들이 기분 좋게 쓰게 해 주신 회사에 진심으로 감사를 드려요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 0]', 5, '2026-05-13 02:23:59')
# (66, '향도좋고 끈적거림없고 너무좋아요', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 1]', 5, '2026-05-13 02:23:59')
# (67, '저는 바디크림 살때 성분도 성분이지만 향을 되게 따지고 구매하는데 이 제품은 향을 맡고 나서 너무 제 취향이라 구매했습니다. 잔향이 오래가지는 않지만 허니 머스크 향으로 달달하면서도 시원해서 기분이 좋더라고요. 게다가 바르면 촉촉하고 보습력도 뛰어나서 건조했던 제 피부들이 많이 괜찮아졌고 가렵거나 하지 않았습니다. 용량도 넉넉하고 가격도 착하고 유통기한도 길어서 안심하고 잘 쓰고 있습니다. 요번에 처음 쓰게 된 OOO 샤워크림인데 너무 만족하고 있어서 앞으로도 계속 사용할 거 같습니다. 추천드려요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 1]', 5, '2026-05-13 02:23:59')
# (68, '꾸준히 사용중인 올인원이에요. 여름에도 겨울에도ㅇㅇㅇ제품 사용합니다. 향기도 은은하고 자극 없어서 좋아요.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (69, '크림 양이 적어요. 제품은 좋다고 하셨어요. 얼굴에서 광이나서 좋아요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (70, 'ㅇㅇㅇ로션을 구매했어요. 촉촉하고 좋습니다. 작은 샘플도 하나 못 받았는데 지금 사면 주네요. 작은 사이즈도 구매하려다가 큰것만 샀는데 아쉬워요. 이번 겨울에 촉촉하게 잘 바를수 있어 좋습니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (71, '유통기한이 짧은 제품이 와서 아쉽습니다. 정품은 속 뚜껑을 열 때 스티커가 있다고 하는데 이 제품은 없습니다. 팩트 테두리가 말라서 갈라져 있어 품질이 불량입니다. 자세한 후기는 사용해보고 다시 올리겠습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (72, '쿠폰 적용을 못해서 비싸게 구매했어요. 그런데 염색해보니 색감이 잘 나오지 않아서 별로예요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (73, '와이프 선물로 구매했어요. 와이프가 발라보니 얼굴이 당긴다고 하네요. 용량도 작은데 촉촉하지도 않고 비싸서 만족스럽지 않네요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (74, '한동안 겨울이 오나 했더니 갑자기 봄이라도 온건지 날이 따스해졌어요 피부 고민도 한결 더해지는 요즘입니다 피부적응기가 팔요한것 같기는 해요 . 처음 발랐을 때 살짝 가려움이 있긴 했지만 뽀루지가 나는건 아니구요 버터같은 제형이다 피부에 문지르면 사르륵 녹아 잘 펴발라지는 신기한 제형입니다. 가볍지 않고 좀 무겁게 느껴지지만 성분이 좋다니 꾸준히 바르고 있습니다~ 촉촉한 느낌 이 오래기는건 좋은 거같은데 주름이나 탄력은 잘모르겠어요. 민감성인데 트러블없이 좋아요.바르면 싹 흡수되고 매트한느낌인데 다음날 세수할땐 엄청 미끈 거리더라구요 그리고 성분 중에 쉐어버터가 있는데 예민한 분들은 트러블이 생길 수도 있다니 주의해야겠습니다. 건성 피부에 추천할만한 크림인 것 같아요 추운 날씨에 다들 감기 조심하세요', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (75, '정말 좋은 남자 향수를 발견해서 여러분에게 알려드리려고 밥도 안 먹고 글을 작성 하고 있습니다!!! 얼마나 좋은 제품이길래 이러는지 궁금하시죠? 바로 리뷰 시작하도록 할게요~!!! 남자 친구가 향수를 자주 쓰는 사람이라 그의 집에 가면 정말 향수가 종류 별로 많아요!! 최근에 갔을 때 자기가 쓰는 여름 향수라면서 하나씩 소개를 해줬는데 이 제품 향을 맡아보니 너무 좋아서 놀랐어요! 여자인 제가 맡아도 좋은 향이라 제가 쓰고 싶었습니다ㅎㅎ 이후에 남자 친구한테 당분간은 이 제품만 쓰라고 했어요^^ 집에 와서도 계속 생각이 나서 아버지 선물로 드리려고 주문 했습니다~ 아버지께서도 좋아 하시면 참 좋을 것 같습니다 ㅎㅎ 남자 향수로 추천 드려요! 향이 정말 좋은 제품이네요~ 아직 모르시는 분들은 가격도 저렴한 편이니 주문해서 사용하시면 좋을 것 같습니다^^', '["보습", "가격", "향", "포장"]', '[0, 1, 1, 0]', 5, '2026-05-13 02:23:59')
# (76, '피부에도 팔에도 저는 바르는데 너무 촉촉합니다. 제형이 리치하지만 유분기가 많지 않아서 건성 복합성 피부에도 좋습니다. 크림보다는 제형이 가볍습니다. 그래도 겨울에 사용해도 될 정도로 충분히 촉촉합니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (77, '발림이 좋았고 커버력은 완벽하지 않았지만 얼굴이 화사해 보여 좋았습니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (78, '계속 쓰고 있는 제품이에요. 바른 듯 안 바른 듯 가벼운 제품이라 메이크업을 해도 밀리지 않습니다. 여름에 사용하기도 적당히 좋은 제품입니다. 유효기한도 넉넉하고 배송도 빠르고 좋습니다.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (79, '햇빛 알레르기가 목과 팔에 심해 햇빛에 나갈 때는 바르는데 살짝 가려움증이 생기네요. OOO나 OO등 비싼 제품에 비교할 때 가성비가 떨어집니다. 끈적임이 많고 무엇보다 자외선차단 잘 되지 않네요. 요즘같이 마스크 쓸 때 색이 묻어나니 신경쓰입니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (80, '양이 넉넉해서 오래 쓸 수 있을 거 같고 저렴해서 구매했어요. 올인원이라 건조하지 않을까 걱정했는데 생각했던 대로 촉촉하지 않네요. 향도 별로고요. 톤업 효과도 없고 진정 효과도 없는 거 같아요.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 2, '2026-05-13 02:23:59')
# (81, '얼굴 뿐만 아니라 팔에도 바르기 편하고 크기가 커서 좋아요~! 엄마랑 동생한테도 하나씩 선물했는데 다들 빅쿠션 크기에 깜놀 발랐을때 쿨링감도 있고 끈적이지 않아서 강추합니다~~', '[]', '[]', 5, '2026-05-13 02:23:59')
# (82, '아이 여드름 때문에 구매 했는데 생각보다 제형이 부드럽고 산뜻하게 닦여서 좋습니다. 저도 가끔 사용하고 있습니다. 세안하고 나면 피부가 부드러워 지는 것 같습니다. 할인해서 저렴히 잘 구매 해서 좋습니다.', '["보습", "가격"]', '[1, 1]', 5, '2026-05-13 02:23:59')
# (83, '이전에 비비만 사서 바르다가 주변 언니가 너무 추천하는김에 세트를 저렴한 가격에 주문했네요 너무 촉촉하게 잘 발리고 일단 커서 너무 좋아요 몇번만 톡톡해두 다 바름 ㅋㅋ어제는 쿠션만 발랐는데 지성이라 조금 번들거리는 느낌있어서 오늘엔 구성품 비비랑 섞어서 발라볼 예정임~^^ 배송총알에 좋은 제품까지 재구매 의사 또있어요~^^', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 5, '2026-05-13 02:23:59')
# (84, '배송 빠르게 왔어요. OOO OO 올인원 안티에이징 상품을 구매했는데 올인원이라 여러가지 제품을 따로 바르지 않아서 좋아요. 아침 저녁으로 바르기에는 용량이 좀 작은 것 같네요.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (85, '유통기한도 2023년 1월까지로 넉넉합니다. 림밤 많이 쓰니까 걍 워낙 유명한 제품이고 ㅇㅇ 같은데 가면 쉽게 볼수 있는 브랜드라서 익숙해요. 용량은 4g으로 사실 엄청 적은양인데 립제품 4g른 꽤나 많은 양이네요. 제조국 Made in Franec 뚜껑을 열면 흰둥한 제형의 립밤이 들어 있어요. 사선형태로 되어 있어서 바르기 편합니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 1]', 3, '2026-05-13 02:23:59')
# (86, '향은 독하지 않습니다. 연한 비누냄새 같아서 좋아요. 발림도 괜찮습니다. 대용량이라 만족합니다. 무엇보다 끈적거리지 않아서 아주 좋네요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 0]', 4, '2026-05-13 02:23:59')
# (87, '안녕하세요~^^ 오늘 소개 해드리고 싶은 제품은 선크림입니다!! 이제 더운 여름이 되어 선크림 찾으시는 분들 참 많으실 것 같아서 제가 써보고 좋았던 제품을 가져왔으니 후기가 구매에 도움이 되셨으면 참 좋을 것 같습니다 :) 일단 이 제품은 선크림 중에서 제일 발림성이 좋은 것 같아요~ 이전에 타사 브랜드 제품 썼을 때는 너무 뻑뻑해서 잘 안 발려서 바를 때부터 기분이 좋지만은 않았습니다... 또한 굉장히 촉촉해서 깜짝 놀랐어요!! 선크림인데 보습력이 정말 뛰어난 제품인 것 같습니다..!! 이거 바르고 출근 하고 들어오면 자외선 지수 심한 날에도 자외선 차단을 잘 해주는 것 같아 아주 만족하면서 사용하고 있답니다~ 선크림 찾으시면 이 제품 추천 드릴게요!! 오늘 소개 해드린 선크림 제품 어떠신가요? 저는 이 제품 꼭꼭 추천 해드리고 싶습니다 :)', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (88, '여름에는 괜찮고 겨울 바디용으로 수분감이 좀 부족한 제품입니다. 겨울이면 몸이 건조하고 각질이 일어나서 바디 제품 꼭 발라야 하는 피부입니다. 제가 새로운 제품을 좋아해서 안 써본 제품이라 이 제품으로 주문하게 되었어요. 택배 받고 바로 사용했어요. 처음 발랐을 때만 촉촉한 느낌이었고 금방 건조함이 느껴집니다. 겨울에 쓰기에는 수분감이 부족한 제품인 것 같아요. 여름에는 바르기 괜찮을 듯하네요. 마음에 들었으면 좋았을 텐데... 겨울용으로 구입한 저는 이 제품 추가 주문은 안 할 생각입니다.', '["보습"]', '[0]', 2, '2026-05-13 02:23:59')
# (89, '여름은 모공이 축축 늘어지는 계절이죠 모공관리에는 모공팩이 개인적으로는 제일 효과적이었는데요 요 모공팩은 확실히 피지를 제거해주면서 모공 관리가 됩니다. 일단 번들거리는 티존부위에 올리고 한 번 롤리하고 바로 세안하면 뽀송뽀송해져요 저희 아이가 사춘기라 유분이 많기도 하지만 여드름도 있어서 여드름 기초 이외에도 모공팩도 같이 해주니까 확실히 좋더라구요 시원한 느낌이라 모공 조여지는 느낌이고 아무래도 겨울보다는 여름에 딱 좋은 제품입니다. 여름에 꼭 필요한 모공팩 리뷰였습니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (90, '새로 한번 써보려고 구매했는데요. 팩이 별로네요. 피부결도 개선이 없고 별 효과가 없어요. 다른 팩보다 보습효과가 그렇게 좋은지도 모르겠어요. 가격도 그렇게 저렴하지 않네요.', '["보습", "가격"]', '[0, 0]', 2, '2026-05-13 02:23:59')
# (91, '클렌징 오일은 ㅇㅇㅇ만한게 없네요. 고가제품도 다 써봤지만 가성비는 말할것도 없고 무엇보다 클렌징이 잘된다는게 좋아요. 다른 제품 쓰다가도 다시 돌아오게 됩니다.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (92, '향이 은은하고 좋아하는 향수라서 또 다시 구매했어요. 포장도 예쁘게 해서 보내 주셨어요. 다른 향으로 사용했었는데 코로나로 인해 면세품 구매가 힘들어 이걸로 바꿔 사용하게 되었어요. 가성비 좋고 주위 사람들이 향이 좋다고 해서 꾸준히 사용하고 있어요. 배송도 빠르고 포장도 이뻐요.', '["보습", "가격", "향", "포장"]', '[0, 1, 1, 1]', 5, '2026-05-13 02:23:59')
# (93, '멀티밤 - 자기전에 한번 사용해봤는데 되게 촉촉해서 다음날까지도 조금 남아있는 정도입니다 당기지않아서 좋았어요! 아쿠아밤-자외선차단기능이라 일상생활할때 사용중인데 멀티밤과 다르게 바르면 뽀송하게 마무리되는 타입이예요! 멀티보다는 조금 수분감이 떨어진 느낌이라 덧바르고있습니다! 상황에따라 골라서 사용하면 효과가 좋을것같아요!', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (94, '예전에는 가격이 괜찮았는데 지금은 가격이 너무 비싸네요. 가격이 올라서 이제는 구매 안 할 것 같아요.', '["가격"]', '[0]', 2, '2026-05-13 02:23:59')
# (95, '지성용이라 뻣뻣할 줄 알았는데 세정력은 좋고 뻣뻣하지 않습니다. 두피에 시원한 느낌도 있어 상쾌해요.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (96, '항상 쓰던 제품입니다. 봄과 여름에 사용하기 좋고 여성스러운 향이라 만족해요. 향이 강하지도 너무 약하지도 않아서 좋네요. 20대 중반부터 지금 30대 중반인데 꾸준하게 사용하고 있습니다. 앞으로도 계속 구매하겠습니다.', '["향"]', '[1]', 5, '2026-05-13 02:23:59')
# (97, '향수 같은 인조 향이라기보다는 자연의 향을 담고 있어서 좋아요. 본디 탈모샴푸 이기 때문에 머리를 다 감고 난 후 린스를 하는 듯한 부드러움은 느껴지지 않아요. 머리에 거품을 몇 분간 나둬 주는 것이 염색효과가 좋네요. 머리를 감고 바로 드라이기를 하니 머릿결이 좋아보이긴하네요. 기술을 이용하여 머리를 감고 있어요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 3, '2026-05-13 02:23:59')
# (98, '친구가 추천을 해줘서 사용하게 된 팩인데 제가 데일리로 매일 사용하고 있어서 추천 드리고 싶어서 가져왔습니다!! 이 제품이 어디가 좋은지 알려 드릴게요 ㅎㅎ 오랜만에 친구를 만났는데 친구 피부가 너무 좋아 보여서 어떤 제품 사용하냐고 했는데 이 제품을 사용한다고 해서 추천 받고 저도 구매를 하게 되었어요 ㅎㅎ 저도 이제 피부 미인이 될 수 있겠구나 생각이 들어서 정말 기대가 많았죠!! 제품 받고 사용을 했는데 와... 진짜 밀착력도 뛰어나고 붙이고 나면 피부가 확실히 좋아진 게 느껴져요!! 뭐랄까 피부결이 부드럽고 촉촉함이 느껴진다고 해야할까...? 확실히 꾸준하게 사용하니까 이전과 달라진 제 피부에 만족하고 있습니다 어떤 팩 사용하실지 모르시는 분이면 이 제품을 구매 해주시면 좋을 것 같아요!!! 완전 추천 합니다', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (99, '매번 쓰던 제품입니다. 신랑이 두피가 민감해서 꼭 이 제품만 쓰려고 고집을 하네요. 가격도 타사이트에 비해 저렴하고 적립금도 많아서 좋네요. 용량이 커서 좋네요. 사진 넣기가 쉽지않아요ㅠㅠ', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (100, '파우치에서 꺼내는 순간 주변의 모든 여자가 알아볼 수 있을 만큼 유명한 제품이죠. OO OOO 립 글로우 사용후기입니다. 저는 진한 색조화장이 안 어울리는 편이라서 립스틱보다는 발색 좋은 립 밤이나 립 글로우를 더 좋아하는데 이 제품이 제 니즈를 딱 충족해 줘요. 색깔 있는 립 밤도 발색이 옅은 립스틱도 정말 많지만 이 제품만큼 딱~ 민낯에 발라도 옅게 화장하고 발라도 어울리는 발색은 아직까지 못 본 것 같아요. 자연스럽게 생기 있는 입술색을 연출해 주고 피부에 촉촉하게 영양 공급까지 해 주니 좋아할 수 밖에요. 예쁜 케이스 덕분에 꺼낼 때마다 기분이 좋은 건 덤이에요. 거짓말 안 보태고 평생 쓰고 싶은 제품이에요. 그냥 강추론 부족하겠어요. 초강추!', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 1]', 5, '2026-05-13 02:23:59')
# (101, '늘 쓰던 제품이 품절이라 새로운 제품을 시도해보고 싶어서 구입했어요. 근데 양도 너무 작고 바르고 나면 번짐이 심해 팬다가 되서 안쓰게 되네요. 가격도 싸지 않았는데 괜히 샀어요. 마스카라 솔이 자그마하니 잘 발라집니다. 솔이 큰거는 바를때 묻는데 이 마스카라 솔은 작아서 묻지도 않아서 사용하기 편하네요. 깔끔하게 잘 발라지고 번짐도 없습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (102, '자연스럽게 새치 커버가 되서 머리 감을때마다 기분전환이 됩니다. 향도 좋고 세정력도 좋아서 완전 좋습니다. 이런 샴푸가 없는거 같습니다. 너무 강추 하는 샴푸입니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (103, '타사제품21호써서21호로주문했는데 너무밝은거같아23호로 교환신청합니다. 잘먹는편이고 퍼프가커서 화장이빨라좋네요. 단 케이스 문양이 제취향은아니네요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 0]', 4, '2026-05-13 02:23:59')
# (104, '여드름 좀 가라앉혀 보려고 사용 중입니다. OOO 제품도 사용하면서 비교 중인데 OO는 제형이 거품 타입이라 부드럽고 촉촉하나 세정력이 약하고 OOO는 거품이 잘 일어나고 세정력이 뛰어납니다. 중요한 건 여드름 완화 효과인데 아직까지는 효과를 알 수 없네요. 효과는 더 써봐야 말할 수 있을 것 같습니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (105, '늘 쟁여두고 사용하고 있어요. 집에 두개가 남아있는데 워낙 구성좋고 가격이 합리적이라서 얼른 구매했어요. 다만 큐어크림단지는 덜어서 사용하기가 좀 불편한점이 있죠. 페추라로 떠서 사용하라고 폐추라를 주시니 위생적이고 다행입니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 1]', 4, '2026-05-13 02:23:59')
# (106, '☆ 추천합니다! 손상된 제 머릿결이 완전 부드러워졌답니다. ☆ 다른 제품 쓰다가 대형마트 보다 싸게 팔고 있어서 구입해 봤어요. 극손상 모발이라 새로운 제품이 필요하긴 했을 때였어요. 잦은 파마와 염색으로 손상된 머리에 매일 드라이기와 매직기도 사용하다 보니 극손상 머리가 끊어지고 잘 빗어지지도 않았어요. 이렇게 손상된 모발에 사용한지 3주쯤 되었을 때 머릿결이 많이 부드러워짐을 느낄 수 있었어요. 우연히 구입한 제품인데 저에게 꼭 필요한 제품을 찾아서 너무 좋고 만족스러웠어요. ☆☆ 극손상 모발로 고민하고 계시면 이 제품이 잘 맞으실 듯합니다. 재구매 의사 완전 있습니다. ☆☆', '["보습", "가격"]', '[1, 1]', 5, '2026-05-13 02:23:59')
# (107, '전에 써보고 가격 할인해서 샀어요. 향도 좋고요 주름도 좋아졌습니다', '["보습", "가격", "향", "포장"]', '[0, 1, 1, 0]', 4, '2026-05-13 02:23:59')
# (108, '괜히 처음부터 대량 구매한 것 같습니다. 제 피부에는 잘 안 맞는지 피부결이 탁하고 거친 느낌이네요. 주위에서 피부 관리해야겠다고 그래요. 꾸준히 믿고 사용하려고 많이 샀는데 후회 되네요.', '[]', '[]', 1, '2026-05-13 02:23:59')
# (109, '아직써보지는않았지만가격이나모든면만족해요 한번써고재구매했는데 만족합니다 더저렴하게잘구입한거같네요 사용하고다시재구매하겠습니다~~~ 상품평작성했으니사은품비비랑스펀지보내주세요 감사합니다그런데퍼프4개는따로들어있는게아닌가요?퍼프4개가안온거같은데누락된거가요?확인해보시고퍼프4개도발송해주세요 사은품은언제받을수있나요?', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 1]', 4, '2026-05-13 02:23:59')
# (110, '가희 처음써봅니다. 향이 참 좋네요. 전성분에 화학약품이 너무 많아서 민감피부에도 괜찮을지 조금 걱정스러워요. 용량이 작아 스틱이 너무 빨리 닳아서 금방 다 쓸것같아요. 오일은 향이 너무 진해요. 선물용으로 산 터라 상품평 쓰고 2개 더 주는 이벤트 매우 좋습니다. 더 좋은 상품 계속 만들어주세요.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 3, '2026-05-13 02:23:59')
# (111, '피부가 보송보송하고 향도 너무 좋습니다. 땀이 많이 나는 편이라 OO 파우더를 자주 사용하는데 자극 없고 좋습니다. 항상 옆에 두고 사용해요. 어린이용 제품이어서 자극도 없어요. 행사 기간 지나서 가격 할인을 못 받아 아쉬워요.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (112, '남편 피부가 지성이라 제품 고를 때 깐깐하게 보고 정하는 편이네요. 유분기가 없어서 좋고 촉촉하고 잘 발리고 끈적거림이 없어 좋다고 합니다. 이 제품 사용해 본 후로는 타 제품은 사용 안 하네요. 꾸준히 잘 사용하고 있어 만족하는 제품이네요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (113, '꾸준히 사용해서 발톱 손톱에 영양을 주고 싶네요. 손발톱에 효과가 있어 튼튼해지면 좋겠습니다. 효과 있으면 재구매 하겠습니다. 발림성 나쁘지 않고 양이 넉넉해서 오래 쓸 수 있을 것 같습니다.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (114, '배송 빠르게 도착했습니다. 품질도 만족합니다. 가격도 마트보다 30%는 저렴해서 좋았는데 사용기한이 짧아서 아쉽네요.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (115, '항상 사용하는 제품인데 몇 년째 촉촉해서 입술 트지 않고 좋습니다. 보습력이 좋아서 떨어지지 않고 루즈전에 항상 사용하는데 좋습니다.', '["보습"]', '[1]', 5, '2026-05-13 02:23:59')
# (116, '이 브랜드 바디로션을 30년 넘게 사용하고 있네요. 계속 사용 중이지만 트러블 전혀 없고 건조한 피부를 촉촉하게 만들어주는 최상의 제품이네요. 바를 때 부드러운 발림성이 좋고 흡수도 잘 되고 끈적거림도 거의 없네요. 건성 피부로 고민이신 분이나 아토피로 고생하시는 분께 적극 추천하네요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (117, '오래전부터 쓰는 제품이라 구매했습니다. 리뉴얼 된 후 커버력이 약해진 게 아쉽지만 보습력 좋고 잘 지워지고 피부톤도 밝아 보입니다. 건성 피부에 좋고 파우더 팩트로 마무리하면 피부가 뽀송해집니다.', '["보습"]', '[1]', 4, '2026-05-13 02:23:59')
# (118, '바를 때 제형이 끈적이고 부드럽게 발리지는 않네요. 피부가 약간 건조해져서 재구매는 생각해봐야겠네요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (119, '며칠 사용을 해봤는데요 모발도 부드럽고 향기는 덤으로 좋습니다. 조금 더 사용해 봐야 얼마나 효과가 좋을지 알겠지만 지금 현재로도 만족합니다. 앞으로도 기대가 됩니다. 꾸준히 사용하겠습니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (120, 'OOO은 건성 피부에 아주 좋습니다. 발림성도 좋고 환절기에 필수적인 제품입니다. 자극적이지도 않고 간편하게 데일리용으로 좋네요. 가격도 저렴하게 구입했습니다.', '["보습", "가격"]', '[1, 1]', 5, '2026-05-13 02:23:59')
# (121, '바르고 금방 말라버리는 스킨 로션이 아니에요 촉촉하고 부드럽게 감싸주네요', '["보습"]', '[1]', 5, '2026-05-13 02:23:59')
# (122, '품질 디자인 가격 배송 전부 마음에 들어요. 케이스 디자인도 취향 저격이고 품질도 괜찮은데 바르고나면 입술에 오일 묻은것 같은 느낌이에요. 개인적으로 그건 별로지만 보습력은 좋습니다. 가격은 할인해서 만족이에요.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 1]', 4, '2026-05-13 02:23:59')
# (123, '끈적이지 않고 사용감이 가볍습니다. 세안 후 깨끗해져서 계속 사용하는 제품이에요. 특별 가격 할인에 적립금 사용해서 저렴하게 샀습니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (124, '다른 제품보다 쿨링감이 좋습니다. 향이 꽤 많이 나서 좋고 오래 지속 되어 좋습니다. 효과도 굉장히 좋은 것 같아요. 보송해서 좋아요.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (125, 'ㅇㅇ는 가을이나 겨울에 주로 사용하기 좋습니다. 봄이나 여름되면 다시 ㅇㅇㅇ로 바꾸고요. 커버력과 무너짐 때문에 ㅇㅇㅇㅇ만 계속 사용 중인데 저렴하게 구매하게 되서 좋아요. 빨리 배송 된 점도 좋네요.', '["가격"]', '[1]', 4, '2026-05-13 02:23:59')
# (126, '늘 쓰는 제품인데 무난하고 좋습니다. 가격도 저렴한 편입니다. 발림성이나 보습도 만족입니다.', '["보습", "가격"]', '[1, 1]', 4, '2026-05-13 02:23:59')
# (127, '진짜 많네요 100장 ㅎ 데일리로 쓰기에 부담없고 에센스가 흘러내리지않아서.좋습니다 ㅎ', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (128, '안녕하세요! 요새 정말 핫한 제품 구매 후기를 알려 드리기 위해 왔습니다!! 이제 제 최애템이 되어 버린 이 제품 후기 바로 시작할게요!! 친구가 소개를 해줘서 구매를 하게 되었는데 사용감이 너무 좋은 것 같아요!! 일단 피부 보정이 정말 잘 되는 것 같아요~ 커버력이 너무 좋아서 제가 모공이 넓은 편인데 이거 바른 날에는 모공이 잘 커버되어 하나도 보이지 않아요!! 지속력도 길어서 아침에 바르면 수정 화장을 안 해도 된다는 점이 정말 인상 깊었습니다!! 당연히 마스크에 묻어나오지도 않아 좋네요!! 추천 드리고 싶은 OOO 파운데이션입니다!! 저는 이 제품에 정착했어요 ㅎㅎ', '[]', '[]', 5, '2026-05-13 02:23:59')
# (129, 'OOO쿠션? 이거 뭐죠~ 쿠션이 이렇게 커버 잘 되기 있나요?? 모공이 넓고 붉은 흉터가 많아 커버력이 떨어지는 쿠션류는 늘 기피대상이었는데 OOO쿠션 써보곤 쿠션 자체에 대한 인식이 달라졌네요 게다가 촉촉하고 색상명처럼 화사한 피부가 됩니다 만족 대 만족 입니다', '[]', '[]', 5, '2026-05-13 02:23:59')
# (130, '빠르게 와서 좋습니다. 가격이 예전보다 조금 오른 듯하네요. 이 제품만 몇 년째 사용 중이네요. 세럼은 이 제품이 제일 좋은 거 같습니다. 향도 제일 좋습니다.', '["가격", "향"]', '[0, 1]', 4, '2026-05-13 02:23:59')
# (131, '처음에 뿌렸을 때는 달콤한 향으로 시작해서 나중에는 묵직하지만 부드러운 느낌의 우디향으로 마무리됩니다. 아무 생각 없이 한번 뿌렸을 뿐인데 몇 번 손을 씻어도 잔향이 그대로 남아있는 것을 보면 지속력이 정말 좋습니다. 남자 향수 이지만 중성적인 향에 가까운 것 같아 좋아요.', '["향"]', '[1]', 5, '2026-05-13 02:23:59')
# (132, '향수의 잔향을 좋아하는데 이 향수는 지속력이 짧아서 잔향을 맡기 어렵네요. 지속력이 길진 않아서 아쉽네요. 잔향 맡기 전에 향이 금방 사라지네요. 향이 금방 사라져서 자주 뿌리다 보면 용량이 작은 편이라 금방 쓰겠어요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (133, '계속 사용하는 제품입니다. 아침에 바르면 하루 종일 촉촉한 느낌입니다. 피부에 자극이 없어 부담 없이 쓰고 있습니다. 여러가지 제품 추천 받아 써봤지만 ooo이 최고인 듯합니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (134, '가격이 비싸서 망설었는데 매장에 가서 발라 보고 바로 샀어요. OO색이 가장 마음에 드는 색이고 매트한 마무리가 좋아서 거의 매일 바르고 다닙니다. 지속력도 나쁘지 않고 립스틱은 역시 OOO이네요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 3, '2026-05-13 02:23:59')
# (135, '평소에 OO 레몬 순 복숭아 리필 번갈아가면서 구매해서 사용하는 사람이고 코튼향 머스크향 포근함이 느껴지는 향 굉장히 좋아하는 1인이라 매우 기대감에 구매했습니다 일단 그냥 기존라인보다 OOO이라 그런지 왠지 모를 고급스러움은 있습니다 유난히 거품이 크리미하긴 하고 손 세정 후에도 촉촉함이 남아 있어요 ㅎㅎ 근데 향이 은근히 있어서 아이들 있는 집에 같이 사용하시기에는 향이 조금 세게 느껴지실 것 같아요 ! 세정력도 좋고 용량도 500ml라서 기존의 250ml보다 더 오래오래 두고 사용할 수 있을 것 같아요 손 자주 씻는 곳에 놓으시는 거 추천드립니당', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 1]', 4, '2026-05-13 02:23:59')
# (136, '부드러운 발림성을 가지고 있긴 하지만 발림성이 좋다보니 흡수까지는 시간이 좀 오래 걸리네요 겉도는 느낌도 들고 보습력이 좋은것도 아니네요. 몇번 덧 발라주는게 보습으로는 효과가 있을거 같습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (137, '예전에는 뜯으면 약간 수분이 있었는데 제형이 너무 고체화 되고 양도 줄은 거 같습니다.', '["보습"]', '[0]', 2, '2026-05-13 02:23:59')
# (138, '가격대비 좋은 상품인 것 같아요. 끈적임도 없고 향도 괜찮습니다. 자극적이지 않아서 만족해요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 0]', 4, '2026-05-13 02:23:59')
# (139, '이 제품 식당이나 병원에 많이 비치 되어 있는 거 보신 적 계시죠? 그만큼 유명한 제품이라 제 후기가 필요할 지는 모르겠지만 혹시라도 모르시는 분들을 위해 작성해봅니다! 손 소독 제품 중에서는 품질이 가장 좋기로 소문난 제품입니다! 일단 성분이 좋아서 손에 자극도 없고 무엇보다 가격이 저렴해서 좋은 제품이에요!! 향도 괜찮고 사은품도 많이 와서 좋은 것 같습니다! 개인적으로 용량이 커서 오래 사용할 수 있는 것이 좋은 것 같습니다!! 지금까지 사용한 손 소독제 중에 제일 좋은 것 같아 추천 드리고 싶습니다!! 코로나가 끝날 때 까지는 계속 이 제품만 사용할 것 같습니다!! 구매 추천 드려요 :)', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 1]', 5, '2026-05-13 02:23:59')
# (140, '피부에 따갑지 않고 순해서 사용하기 좋습니다. 그러나 건조한 느낌이 있어요. 유분기가 없어서 화장하기 좋으나 발림성은 떨어지네요. 순해서 아이와 함께 발라도 좋고 데일리용으로도 괜찮은 듯 합니다. 물에 들어갔다 나올 때마다 한 번씩 발라줬는데 적당히 타는 게 효과가 괜찮은 듯 합니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (141, '항상 사용하고 있는 OOO입니다. 향도 진하지 않고 은은해서 좋아해요. 다만 환율이 올라서 그런지 가격이 높습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 3, '2026-05-13 02:23:59')
# (142, '쓰던 다른 제품이 있었는데 저렴하게 나와서 바로 주문했습니다. 케이스도 고급스럽고 커버력도 좋습니다.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 1]', 4, '2026-05-13 02:23:59')
# (143, '오늘 제품을 받고 처음 사용해 봤는데 청소하면서 돌아다녔습니다. 사용 후에 얼굴이 촉촉하지는 않았고 생각보다 제품에 콜라겐 성분이 부족한 것 같습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (144, '데일리로 사용하기 좋아요. 케이스 빡빡해서 잘 열리지 않아 사용하기는 좀 불편하네요. 색깔도 예쁘고 발색력도 너무 좋아요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 3, '2026-05-13 02:23:59')
# (145, '겨울에 사용하기 좋아 늘 구매하는 핸드크림이에요. 보습력은 이 라인이 좋은 것 같은데 발림성은 노란색 라인이 가장 좋아요. 여름에는 바르기 산뜻하지 않은 것 같고 이 제품은 가을 겨울에 바르기 좋을 것 같아요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (146, '여드름 때문에 사용하는 중입니다. 조금 당기네요. 에센스랑 같이 사용하면 덜 당깁니다. 효과는 더 써봐야 알 것 같아요.', '[]', '[]', 2, '2026-05-13 02:23:59')
# (147, 'OO멀티밤을 입술 주위에 발라봤는데 보습이 잘 되진 않네요. 미스트도 향이 별로고요. 오일은 번들거려요. 용량도 작아요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (148, '일단 용량이 마음에 들어요. 파우더 제형은 커버력과 뭉침이 거의 없어서 선호해요. 처음 써보는데 기대됩니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (149, '생각보다 케이스가 커서 깜짝 놀랬어요~~ 커버력도 괜찮구요^^ 잘 사용할것같아요', '["포장"]', '[1]', 4, '2026-05-13 02:23:59')
# (150, '이제 사용중이라서 효과는 더써보아야 될 듯 하구요. 머리두피가 개운하고 청량감은 있습니다. 지성피부인 아들도 사용하고 좋다고 하네요', '[]', '[]', 4, '2026-05-13 02:23:59')
# (151, '이것저것 잘 챙겨바르는 편이 아닌데 이 제품이 한 번에 해결된다고 해서 구매해 봤습니다. 그런데 생각보다 촉촉하지 않네요. 할인 기간을 놓치는 바람에 비싸게 샀는데 가격대비 용량이 작은 거 같아요.', '["보습", "가격"]', '[0, 0]', 2, '2026-05-13 02:23:59')
# (152, '요즘 기분전환도 할겸 립스틱을 바꾸고 싶어 쇼핑 하다가 우연히 OO OOO 립스틱을 발견했는데요. 립스틱의 디자인이 너무 마음에 들어 구매해봤습니다. 동그랗게 나와있는 부분을 누르면 또깍하며 제품이 튀어나오는 디자인이 좋아요.OO 립스틱은 바를 때 매트해서 그런지 좀 뻑뻑한 감이 있더라고요. 색은 바른듯 안바른듯 자연스럽게 발려 좋네요. 두껍지 않게 발리고 밀착력도 괜찮았습니다. 생얼에 립만 바르시는 분들 화장 진하게 하는 거 싫어하시는 분들에게 잘 맞을 것 같아요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 1]', 4, '2026-05-13 02:23:59')
# (153, '몇년째 OOO만 사용하고 있어요. 입술이 얇아 립스틱을 바르면 예쁘지 않아서 발색되는 립글로우를 찾다 사용하게 되었어요. 시간이 지나며 색상도 여러가지로 선택하기 좋아졌고 보습 잘 되고 발색력도 좋아 만족합니다. 가격이 비싸 살 때마다 부담스럽지만 이번에는 할인 이벤트에 할인 쿠폰까지 적용 받을 수 있어 저렴하게 구입할 수 있었어요. 앞으로도 계속 사용할 제품입니다. 할인 이벤트 자주 해주세요.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (154, '세정력은 좋은데 향긋한 허브 향이 아니고 약품 냄새 같아서 재구매 의사는 없습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (155, '편하게 사용하시라고 시골에 계신 아빠에게 선물로 보내드렸네요. 발라보니 촉촉하지 않다고 하시네요. 얼굴 땡김도 있고 건조하고 향도 강하다 하십니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (156, '자주 쓰던 제품이어서 구매했고 이벤트 할때 싼가격에 잘 구매했습니다. 겨울에 사용하기 적합해요.보습력이 뛰어난 좋은 제품입니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 5, '2026-05-13 02:23:59')
# (157, '헤어에센스는 늘 이것만 사용해요. 머릿결이 부드럽고 좋아 보여서 만족하네요. 가격도 비싸지 않고 좋습니다.', '["보습", "가격"]', '[1, 1]', 5, '2026-05-13 02:23:59')
# (158, '보습력 발림성 모두 좋습니다. 향도 무난해서 가족 모두 쓰기 적당한 것 같아요. 할인 행사로 저렴하게 구매하게 되었는데 모든 면에서 만족해요. 특히 요즘 같이 건조할 때 부담없이 쓰기 좋습니다. 할인 행사 하면 또 구매할게요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 0]', 5, '2026-05-13 02:23:59')
# (159, '포장이 정말 잘 되어있습니다. 거품이 부드럽고 향도 좋습니다. 세정력도 좋아요. 잘 쓰겠습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 1]', 4, '2026-05-13 02:23:59')
# (160, '진정만 해주네요. 보습은 1도 없습니다. 제형이 묽어서 발림성 좋고 사용감 가볍습니다. 바로 흡수되고 흡수되자마자 말라서 건조합니다. 진정작용은 나름 역할을 하는 것 같습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (161, '염색 후 사용하니 한달이상 지속있는 컬러감이 좋습니다. 처음에는 시원했는데 두번째부터는 청량감이 없습니다. 모발은 샴푸만 써서 그런지 정전기가 나서 린스와 같이 사용합니다.', '[]', '[]', 3, '2026-05-13 02:23:59')
# (162, '백화점에서 구입하다가 저렴하게 인터넷으로 주문했습니다. 사용하기 편리하고 좋습니다. 아침에 옷에 뿌리고 출근 하면 지속력이 약해서 아주 작은 유리 스프레이 병에 조금 담아 퇴근시에 다시 뿌립니다. 향이 좋아서 다음에도 구입 하려고 해요.', '["보습", "가격", "향", "포장"]', '[0, 1, 1, 0]', 4, '2026-05-13 02:23:59')
# (163, '주변에서 추천받아 주문해봤는데 유통기한도 짧고 설명서도 없어요. 물건만 보내와서 뒷면에 영어 설명보고 사용해야 할 것 같네요. 샘플도 하나도 없어요.', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 2, '2026-05-13 02:23:59')
# (164, '평소에 머릿결 관리에 관심이 많아 헤어 에센스 제품은 정말 여러 가지를 사서 써봤습니다!! 안 써본 제품이 없는 와중에 이 제품을 알게 되어서 바로 구매해서 써 봤는데 너무 좋아서 여러분들에게 알려드리고자 버선발로 글을 작성하게 되었습니다~!!!! 평소에 쓰던 제품은 바르고 나면 머리카락이 끈적거리고 스타일링도 잘 되지 않아서 쓸까 말까 고민을 하고 있었습니다... 그러던 와중에 딸 아이가 친구가 이 제품을 쓰는데 정말 좋다고 해서 궁금해서 바로 구매를 하게 되었습니다!! 배송은 살짝 느려서 기다리다가 지칠 뻔했지만 받자마자 사용을 해봤는데 너무 좋았습니다!! 가장 좋았던 점은 머릿결이 촉촉해집니다...!! 뭐랄까 머리카락에 수분감이 꽉 차 있는 기분이라 정말 좋았던 것 같아요~ 딸 아이는 이 제품 쓰고 남자친구를 만나면 남자친구가 향이 정말 좋다고 해서 만족한다고 해요~^^ 촉촉한 머릿결을 원하시는 분들은 꼭 한 번 써보시길 추천합니다!! 저는 왜 이제야 이 제품을 알게 됐는지 싶네요~ 빨리 써 보세요!! 추천 합니다 ㅎㅎ', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (165, '머릿결이 부드럽고 향기도 오래가네요. 양도 많앗니 좋아요', '["보습", "가격", "향"]', '[1, 1, 1]', 5, '2026-05-13 02:23:59')
# (166, '30대가 되니 기초케어에도 신경이 쓰이더라구요ㅠㅠ그래서 동생과 같이 구매하게 되었답니다 바로 OO OOO 단백질 크림입니다^^^ 개별구매는 비싼것 같아 세트를 구입해서 동생과 엄마와 같이 쓰기로 했어요 충분한 구성에 합리적인 가격도 너무 좋아서 뿌듯했네요 ㅋㅋ 케이스도 금색으로 너무 고급지더라구요 선물해도 될 만큼 있어 보였어요 ㅋ 단백질 알갱이가 톡톡 터지며 촉촉하게 흡수 되어 피부 속 깊이 수분과 단백질이 꽉 차는 것 같아요 ㅎㅎ 동생은 당김이 좀 있다고 하네요...보습력도 생각보다는 별로 라고 ....무튼 엄마와 나는 만족했어요 엄마는 주름에도 효과가 있는 것 같다고 하시네요 ㅋㅋ', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 1]', 4, '2026-05-13 02:23:59')
# (167, '유명 뷰티 인플루언서가 추천한 선크림이 특히 잘나가는 OO의 붉은기 진정 크림 OOO 크림을 사용해 봤어요. 먼저 고백할게요. 저는 얼굴에 붉은기가 원래 없어서 붉은기가 진정되는 효과는 알 수가 없었어요. 그러면서 왜 샀냐고 물으신다면... 싸기도 하고 OO 화장품이 궁금하기도 했거든요. 그런데 금액이 저렴한 데에는 다 그럴 만한 이유가 있나 봐요. 바르고 나서 멀쩡한 얼굴에 여드름이 올라왔네요. 아무래도 제품에 유분기가 많은 편이라서 그런가 봐요. 지성피부인 분들은 피하시는 게 좋겠어요. 오늘도 피해야 할 화장품 리스트에 +1 하고 저는 이만 총총...', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 2, '2026-05-13 02:23:59')
# (168, '정말 촉촉하고 간편하게 뿌리기에 좋은 거 같습니다^^~ 평생 쟁여놔야 할 것 같은 아이템이에요^^!!', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (169, '운전할 때 건조하기도 하고 주름이 신경 쓰여서 구입했어요. 며칠 써보고는 있는데 얼굴 당김이나 푸석함이 좋아지지는 않네요. 주름에도 좀 더 써봐야 효과는 알 수 있을 것 같아요. 얼굴이 땡글땡글 탄력있어 보이고 주름이 펴진듯해요 ...넘 좋아요 주머니에 넣어가지고 수시로 잘 바름', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 3, '2026-05-13 02:23:59')
# (170, '쉐이빙젤은 비교적 오래 쓰는 편인데 쉐이빙폼 양이 많지 않아 얼마 못 쓸 것 같아요. 가격은 저렴했어요.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 3, '2026-05-13 02:23:59')
# (171, '선물도 하고 저도 써봤습니다. 첫 향은 달달함이 강해서 별로지만 잔향은 좋은 거 같아요. 향이 처음에는 독한데 잔향이 적당히 달달해서 좋습니다.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 3, '2026-05-13 02:23:59')
# (172, '사용해보니 너무좋아요~~ 얼굴에 뾰루지가 나서 손으로 잡아뜯은 상처에 퓨어크림바르니 깨끗해졌어요~ 너무좋아 재구매합니다^^', '[]', '[]', 5, '2026-05-13 02:23:59')
# (173, '바르니 주름이 옅어져 너무나 영 (즉 젊어보인다) 해보이네요 벌써 친구하테 자랑하면서 추천 했어요 피부가 좋아보인다니 계속 구입해 쓰고싶어요', '[]', '[]', 5, '2026-05-13 02:23:59')
# (174, '안녕하세요~ 오늘은 민감성이신 분들에게 토너 하나 추천해 드릴게요! 바로ㅇㅇㅇ 토너입니다! ㅇㅇ의 ㅇㅇㅇㅇㅇ 라인은 순하다고 잘 알려져 있는 만큼 이 제품은 따갑다거나 자극적이지 않아서 좋았어요ㅎㅎ 찾아보니 주의 성분 0개로 성분이 착하네요! 점성이 있는 제형이다기 보다는 주르륵 흘러내리는 물 토너라 손으로 바르는 것보다 토너팩으로 사용하거나 화장솜을 이용해서 바르는 것을 추천드릴게요! 물 토너이다 보니 건성 분들은 사용하실 때 건조함을 느끼실 거예요. 그럴 땐 여러번 레이어드 해 주시는 것을 추천드립니다! 민감성이신 분들은 이거 꼭 쟁여놓기~~', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (175, '지인의 추천으로 온라으로 저렴한 가격으로 구매를 했습니다. 며칠 사용해보고 후기 남깁니다. 개인적으로 좋아하는 향이라 상당히 만족하구요. 주변에서는 취향이 전혀 달라 향이 별로 안 좋다고 하는 지인이 있긴 합니다. 샘플이랑 제품구성도 만족스럽습니다.', '["가격", "향", "포장"]', '[1, 1, 1]', 4, '2026-05-13 02:23:59')
# (176, '마침 쓰던 파우더가 떨어 지려는 참에 구매해서 처음으로 사용해봤는데 기대 이상으로 너무 좋습니다. 가격도 저렴하고 발림성이 너무 좋습니다. 이거 다 쓰면 재구매 해서 또 사용해보겠습니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 5, '2026-05-13 02:23:59')
# (177, 'OOO 에센스는 처음으로 구매했습니다. 저렴한 가격으로 잘 샀습니다. 머리 감고 바르면 부스스한 머릿결이 차분해지는 느낌입니다. 잘 사용하겠습니다.', '["보습", "가격", "향", "포장"]', '[1, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (178, '지인이 추천해서 구매했습니다. 사용해보니 발이 깔끔하게 세정되고 개운해지는 느낌입니다. 제품이 마음에 들어 앞으로도 계속 사용할 예정입니다.', '[]', '[]', 4, '2026-05-13 02:23:59')
# (179, '땀나서 흘러내리는것도 없고 스틱이라 휴대성도 쉬워서 좋네요 또 구매할게요 ○○○는 화장품세트부터 좋은데 썬스틱도 괜찮네요 양이 작아 좀 아쉽네요', '[]', '[]', 4, '2026-05-13 02:23:59')
# (180, '가격이 비싸지만 군대 간 아들 사줬어요. 요즘 군에서도 피부관리를 많이 하고 인기 품목이라고 하네요. 스킨로션도 안 바르던 아들이 군에 가서 바르기 시작했습니다. 수분감이 조금 부족하다고 합니다. 그래도 너도나도 다 피부관리를 하니 같이 하게 되나 봅니다.', '["보습", "가격"]', '[0, 1]', 3, '2026-05-13 02:23:59')
# (181, '배송도 빠르고 가격도 저렴해서 좋은데 염색은 잘 안되는 듯하네요. 염색약도 손에 묻어나고 이틀 정도 물도 빠지네요.', '["가격"]', '[1]', 3, '2026-05-13 02:23:59')
# (182, '수년째 쓰고 있는데 역시 향이 좋습니다. 사은품도 엄청나게 이것저것 와서 놀랐습니다. 많이 판매하세요.', '["보습", "가격", "향", "포장"]', '[0, 0, 1, 0]', 4, '2026-05-13 02:23:59')
# (183, 'OO 향수 중에 이 향수가 베스트인 것 같아요. 남녀가 같이 쓰기도 좋고 여름에 쓰기에도 좋고 향이 너무 마음에 드네요.', '["향"]', '[1]', 5, '2026-05-13 02:23:59')
# (184, 'OOO 로션을 발라봤더니 수분감 있고 이마의 좁쌀도 모두 들어갔어요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (185, '아는 지인이 OOO 써~ 보라해서 구입했지요 향기도 좋고 용량도 많으네요. 나이들면서 머리결이 부시시 했는데~ 좋은제품을 만나서 너무좋아요.다른분들도 써보세요.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (186, '수분크림 저녁에 바르고 오전늦게 까지 촉촉하게 유지되고 적립금 활용 저렴한가격에 구매해서 잘사용하고있어요', '["보습", "가격"]', '[1, 1]', 5, '2026-05-13 02:23:59')
# (187, '잦은 손 소독제 사용으로 거칠어진 손을 조금이라도 살려보고자 구입했습니다. 묵직한 느낌의 크림으로 빨리 흡수되지는 않지만 꾸준히 바르니 피부가 좋아지는 게 느껴지네요.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 4, '2026-05-13 02:23:59')
# (188, 'OO님이 개발에 참여 하신 거라 사기 전부터 정말 기대가 많았습니다~ 가격도 저렴한 편에 속해서 구매 했어요~~ 써 보고 너무 좋아서 긍정 후기 남기려고 왔습니다!!!! 다들 선크림 어떤 제품으로 사용하고 계시나요?? 아직 이 제품 안 써보셨으면 추천 드릴게요~ 무기자차 성분이 순해서 어떤 피부 타입에도 잘 맞는 제품인 것 같아요~ 발림성도 부드럽고 선크림 특유의 냄새가 심하지 않아서 좋은 것 같습니다 ㅎㅎㅎ 무엇보다 자외선 차단 효과가 뛰어나서 밖에 나갈 때 꼭 바르고 나가는 필수템인 것 같습니다~^^ 선크림 제품 찾으시면 이 제품 추천 해드릴게요~ 이 제품 바르시고 여름철 자외선 차단 하시고 피부 보호 하세요~ :)', '["보습", "가격", "향", "포장"]', '[0, 1, 1, 0]', 5, '2026-05-13 02:23:59')
# (189, '배송도 빠르고 촉촉한 느낌이 오래 가서 피부가 자극없이 편하고 좋습니다', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (190, '너무 좋습니다. 혜택 모아서 저렴하게 구매했습니다. 색상도 잘 맞습니다. 마스크에 묻어나는 점은 아쉽습니다. 케이스가 너무 고급스러워요.', '["보습", "가격", "향", "포장"]', '[1, 1, 1, 1]', 4, '2026-05-13 02:23:59')
# (191, '저는 자연스러운 거 좋아해서 화장도 연하게 자연스럽게 하는데요. 이 제품은 발색력이 저한테 살짝 과하게 느껴졌습니다. 색을 밝은 색을 사서 그럴 수 도 있겠지만 다른 제품이랑 비교해봤더니 제품 색상의 채도가 살짝 높게 나온거 같더라고요. 또 착색력도 뛰어나서 바르고 잘 안 지워지니 양 조절을 충분히 한 후에 소량만 발라야 적당히 발색됩니다. 틴트도 계속 바르면 건조해지는데 어쨋든 착색력이랑 지속력이 뛰어나서 좋게 생각하면 훌륭한 제품 이라고 생각합니다. 말 그대로 픽싱력이 좋으니 한번 테스트해보고 구매해보는 게 좋을 거 같아용!', '[]', '[]', 3, '2026-05-13 02:23:59')
# (192, '싼맛에 사용하고 있는데 ㅇㅇㅇ 팩치고는 수분감도 적고 밀착력도 떨어지고 기능을 제대로 못하네요. 팩 분리할때도 다른 팩에 비해 손이 많이 가서 사용하기 불편하네요. 딱히 수분충전되는 느낌이 없네요.', '["보습", "가격"]', '[0, 1]', 2, '2026-05-13 02:23:59')
# (193, '바르고 끈적여서 신경이 많이 쓰이고 피부가 좋아지지 않네요. 성분도 안 좋은 것 같고 용량도 아쉬워 재구매는 없습니다.', '[]', '[]', 2, '2026-05-13 02:23:59')
# (194, '주름 관리가 쉽고 촉촉해서 아내가 너무 만족해 하네요. 처음에는 지인이 선물해 줘서 사용해 봤는데 만족도가 높아 OO쇼핑에서 구성 좋을때 추가구매 합니다.', '["보습", "가격", "향", "포장"]', '[1, 0, 0, 0]', 5, '2026-05-13 02:23:59')
# (195, 'OOO에서 인터넷 보다 저렴하게 구입했어요. 한 개만 발라도 되니 편해서 좋아요. 다른 사람에게 추천하게 되네요.', '["보습", "가격", "향", "포장"]', '[0, 1, 0, 0]', 4, '2026-05-13 02:23:59')
# (196, '피부 좋은 직장후배의 추천으로 알게 된 OO OOO 크림팩!!! 이제품을 쓰고 나의 피부도 이렇게바뀔 수 있다는 것에 놀랬답니다 우후~~ 보통 팩하면 얼굴에 붙이고 나면 줄줄 흘러서 아무것도 못 하는데 콜라게 크림팩은 붙이고 마음껏 움직일 수 있어서 무엇보다 좋았구요 필오프 타입이라 잘 뜯어지지 않을까 걱정했는데 부드럽게 잘 뜯어지더라구요. ㅎㅎ 아니 그런데 떼고 나니 촉촉하고 윤기도 나면서 피부에 광이나는거예요 정말 너무 좋았어요 ^^ 다음날 화장도 잘 먹어서 저는 일주일에 2~3번씩 쓰고 있답니다 ㅋㅋ 계속 사용하려니 양이 적어서 부담이 되네요 ㅠㅠ 그래도 재구매 했어요 ㅋㅋ', '["보습", "가격"]', '[1, 0]', 4, '2026-05-13 02:23:59')
# (197, '향수 필요해서 찾아 보다가 이 제품 할인 해서 구매하게 되었는데 품질이 생각보다 좋지는 않네요!! 저는 사용하고 좋지 않아서 후기 작성합니다... 유통기한도 엄청 짧은 제품을 받아서 기분이 안 좋고 용기가 너무 무거워 좋지 않네요.... 향은 기대보다 좋지 않아서 아쉬운 것 같습니다.. 잔향도 살짝 너무 별로에요... 괜히 산 것 같다는 생각이 듭니다!! 가성비 없는 것 같아요! 이거 뿌리고 동생한테 물어보니까 향이 별로라고 하는 걸 보면 저만 그렇게 느끼는 게 아닌 것 같습니다...!! 추천 하고 싶지 않습니다! 저는 그냥 다른 향수 구입해서 사용하고 있네요~', '["보습", "가격", "향", "포장"]', '[0, 0, 0, 0]', 1, '2026-05-13 02:23:59')
# (198, '시원하다길래 반신반의하면서 구매했어요 엄청 시원한건아니지만 그래도 시원한감은 있어요 톤업이되네요', '[]', '[]', 3, '2026-05-13 02:23:59')
# (199, '꾸준히 애용하고 있습니다. 사용기한도 넉넉합니다. 특히 향이 은은하여 좋네요. 보습력도 좋고요. 단종 없이 오래 생산해 줬으면 좋겠습니다. 제가 써 본 중에 제일 좋은 바디로션이에요.', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 0]', 5, '2026-05-13 02:23:59')
# (200, 'OO 자음 2종 기획 세트로 구매하면 구성품으로 여행용 작은 세트 4개가 들어있네요 여행갈 때 넣어가서 사용하기 좋습니다 순하고 제형도 부드럽습니다 향도 은은하고 좋습니다', '["보습", "가격", "향", "포장"]', '[1, 0, 1, 1]', 4, '2026-05-13 02:23:59')

# %%
# !apt-get -y install fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %% [markdown]
# * 세션 다시시작

# %%
# %%writefile app.py
import streamlit as st
import sqlite3
import json
import ast
import os
import operator
from typing import TypedDict, Optional, Dict, Any, Literal

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import openai
import re

from typing import TypedDict, Annotated, List, Optional, Literal, Dict, Any
from langgraph.graph.message import add_messages
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langgraph.graph import END, START, StateGraph, MessagesState
from langchain_openai import ChatOpenAI

# ==================================================
# 0. 기본 설정
# ==================================================
DB_PATH = "user_review_db.db"
ASPECT_LIST = ["보습", "가격", "향", "포장"]

st.set_page_config(page_title="상품 리뷰 분석 Agent", layout="wide")

# 한글 폰트 설정
def set_korean_font():
    candidates = [
        "/usr/share/fonts/truetype/nanum/NanumGothic.ttf",
        "/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf",
    ]
    for path in candidates:
        if os.path.exists(path):
            fm.fontManager.addfont(path)
            font_name = fm.FontProperties(fname=path).get_name()
            plt.rcParams["font.family"] = font_name
            break
    plt.rcParams["axes.unicode_minus"] = False

set_korean_font()

# ==================================================
# 1. Agent (1차 분석: analyzer / critic / supervisor)
# ==================================================
class ReviewState(TypedDict):
    messages: Annotated[list, add_messages]
    input_review: str
    max_num: int
    current_num: int
    score: int
    next_step: Optional[Literal["analyzer", "critic", "end"]]
    result: dict
    aspect_list: List[str]
    criti_score: str

visor_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
analyzer_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
criti_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)

def analyzer_node(state: ReviewState):
    review = state.get("input_review") or ""
    result = state.get("result") or {}
    aspect_list = state.get("aspect_list") or []
    score = state.get("score") or 0
    feedback = state.get("criti_score") or "없음 (최초 분석)"

    sys = """
너는 화장품 리뷰 분석 전문가야.
다음 지침에 따라 입력받은 사용자의 리뷰를 분석해줘.
만약 [수정 요청 피드백]이 제공된다면, 이전의 실수를 교정하여 결과를 다시 작성해야 해.

[지침]
1. 제시된 [후보 속성] 중에서 리뷰 내용과 일치하는 것을 추출해. **단, '성능', '효과'처럼 포괄적인 단어가 쓰였더라도 문맥상 화장품의 기능(예: 보습력)을 뜻한다면 유연하게 해석해서 해당 후보 속성으로 매칭해줘.**
2. **중요: 'aspect' 리스트에 담긴 속성의 순서는 반드시 [후보 속성]에 나열된 순서를 유지해야 해.**
3. 각 속성에 대한 만족도를 판별해서 만족/긍정은 1, 불만족/부정은 0으로 기록해.
4. 'label' 리스트의 값은 'aspect' 리스트의 순서와 1:1로 정확히 매칭되어야 해.
5. [중요: 별점 산정 규칙]
- 입력된 [별점 숫자]가 0보다 크면 해당 값을 그대로 사용해.
- 입력된 [별점 숫자]가 0이라면, 리뷰 원문의 뉘앙스를 분석하여 네가 직접 1~5점 사이의 별점을 책정해.(매우 만족: 5, 만족: 4, 보통: 3, 불만족: 2, 매우 불만족: 1)
6. 리뷰 내용이 후보 속성과 명확하게 연결되지 않는 경우에는 aspect와 label을 빈 리스트([])로 반환해.
7. 결과는 반드시 아래의 JSON 형식으로만 출력하고, 코드펜스(```)나 추가 설명은 절대 포함하지 마.

[출력 형식]
{
  "review": "리뷰 원문",
  "aspect": ["추출된 속성 리스트"],
  "label": [각 속성에 대응하는 1 또는 0 리스트],
  "score": 별점숫자
}
"""
    human = f"""
[리뷰 원문]
{review}

[후보 속성]
{aspect_list}

[별점 숫자]
{score if score else 0}

[수정 요청 피드백]
{feedback}
"""
    resp = analyzer_llm.invoke([SystemMessage(content=sys),
                                HumanMessage(content=human)])

    raw = resp.content.strip()
    try:
        data_dict = json.loads(raw)
    except json.JSONDecodeError:
        cleaned = re.sub(r"^```(?:json)?\s*|\s*```$", "", raw, flags=re.MULTILINE).strip()
        try:
            data_dict = json.loads(cleaned)
        except json.JSONDecodeError:
            data_dict = {
                "review": review,
                "aspect": [],
                "label": [],
                "score": score,
            }

    data_dict.setdefault("review", review)
    data_dict.setdefault("aspect", [])
    data_dict.setdefault("label", [])
    data_dict.setdefault("score", score)

    return {
        "messages": [AIMessage(content=f"[Analyzer Result]\n{resp.content}")],
        "result": data_dict,
        "criti_score": ""
    }


def critic_node(state: ReviewState):
    review = state.get("input_review") or ""
    aspect_list = state.get("aspect_list") or []
    result = state.get("result") or ""
    criti_score = state.get("criti_score") or ""
    current_num = state.get("current_num") or 0

    sys = """
너는 리뷰 분석 결과의 정확성을 검증하는 품질 관리(QA) 전문가야.
Analyzer가 추출한 결과가 리뷰 원문의 내용과 논리적으로 일치하는지 검토해줘.

#검토 지침
1. 일관성: 추출된 'aspect'가 리뷰 원문에 직접 언급되었거나, **문맥상 의미가 일치하는지 확인해 (예: '성능' -> '보습' 등 포괄적/유의어 매칭 허용).**
2. 정확성: 각 'aspect'에 매칭된 'label'(1: 만족, 0: 불만족)이 리뷰의 맥락과 맞는지 확인해.
3. 형식: 결과가 약속된 JSON 형식을 유지하고 있는지 확인해.
4. 순서: **[중요] 추출된 'aspect'들은 [후보 속성]에 나열된 상대적 순서를 유지해야 해.**

#출력
[FEEDBACK]
- ...
[VERDICT]
VERDICT: OK
또는
VERDICT: REVISE
"""
    human = f"""
[리뷰 원문]
{review}

[후보 속성]
{aspect_list}

[Analyzer의 분석 결과]
{result}
"""
    resp = criti_llm.invoke([SystemMessage(content=sys),
                             HumanMessage(content=human)])
    current_num = current_num + 1
    return {
        "messages": [AIMessage(content=f"[CRITIC RESULT]\n{resp.content}")],
        "criti_score": resp.content,
        "current_num": current_num
    }


def supervisor_node(state: ReviewState):
    print("-다음 경로 탐색중...-")
    if not state.get("result"):
        next_step = "analyzer"
    elif not state.get("current_num"):
        next_step = "critic"
    else:
        criti = state.get("criti_score") or ""
        if "VERDICT: OK" in criti:
            next_step = "end"
        elif "VERDICT: REVISE" in criti and state.get("current_num") <= state.get("max_num"):
            print("-!재분석이 요구됩니다.!-")
            next_step = "analyzer"
        else:
            next_step = "end"
    print(f"-{next_step}으로 이동합니다.-")
    return {"next_step": next_step}


def route_next(state: ReviewState):
    return state["next_step"]


builder = StateGraph(ReviewState)
builder.add_node("analyzer", analyzer_node)
builder.add_node("critic", critic_node)
builder.add_node("supervisor", supervisor_node)

builder.add_edge(START, "supervisor")
builder.add_conditional_edges("supervisor", route_next,
    {"analyzer": "analyzer",
     "critic": "critic",
     "end": END}
)
builder.add_edge("analyzer", "supervisor")
builder.add_edge("critic", "supervisor")

agent_app = builder.compile()


# ==================================================
# 1-2. ★ NEW ★ 별점 1~2점 리뷰 피드백 Agent
#       (router → 전문가 노드들 → aggregator)
# ==================================================
class AnalyzerState(TypedDict):
    messages: Annotated[list, add_messages]
    review: str
    aspect: List[str]
    label: List[int]
    next_node: List[str]
    result_list: Annotated[List[str], operator.add]
    final_result: str


router_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
price_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.7)
performance_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.3)
Texture_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.2)
Design_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0.7)
Service_llm = ChatOpenAI(model="gpt-4.1-mini", temperature=1)


def router_node(state: AnalyzerState):
    aspect = state.get("aspect") or []
    label = state.get("label") or []

    sys_msg = '''
너는 고객 리뷰의 불만 사항을 파악하고 해결할 전문 부서를 배정하는 라우터(Router) 에이전트야.
입력된 [aspect] 리스트와 [label] 리스트의 규칙을 분석하여, 불만족으로 평가된 속성을 해결할 전문가 에이전트 목록을 출력해.

[전문가 그룹 및 담당 속성]
1. price_node: 가격, 할인, 가성비, 구성
2. performance_node: 보습, 커버력, 발색, 자외선 차단, 톤업, 진정, 세정력, 손상케어, 주름개선, 클렌징, 효과, 피부결, 피부, 품질, 성분, 소독효과
3. texture_node: 발림성, 흡수력, 사용감, 제형 밀도, 제형, 유분감, 밀착력, 번짐, 자극, 향
4. design_node: 디자인, 색감(색상), 사이즈(크기), 휴대성, 편의성, 위생, 포장
5. service_node: 배송, 만족도, 재구매, 피부타입, 사은품

[분석 및 라우팅 지침]
1. 매칭 규칙: [aspect]와 [label]의 요소는 같은 인덱스로 1:1 매칭되어 있어.
2. 불만족 식별: [label] 값이 0인 인덱스를 모두 찾아.
3. 속성 추출: 찾아낸 인덱스와 동일한 위치에 있는 단어들을 [aspect]에서 추출해.
4. 에이전트 매칭: 해당 에이전트(LLM) 이름을 매칭해.
5. 중복 제거.
6. 우선순위: performance_node, texture_node가 있으면 맨 앞으로.
7. 예외 처리: 0(불만족)이 없으면 ["service_node"]를 출력해.

[출력 형식]
반드시 쌍따옴표가 포함된 올바른 JSON 리스트 형식으로만 응답해.
예) ["performance_node", "texture_node", "design_node"]
    '''
    user_msg = f"""
[aspect]
{aspect}

[label]
{label}
"""
    response = router_llm.invoke([SystemMessage(content=sys_msg),
                                  HumanMessage(content=user_msg)])
    content = response.content.strip()
    if content.startswith("```"):
        content = content.replace("```json", "").replace("```", "").strip()

    try:
        destination = json.loads(content)
    except json.JSONDecodeError:
        destination = ["service_node"]

    return {"next_node": destination}


def _build_expert_node(llm, role_name, area, target_attrs, persona):
    """전문가 노드 공통 빌더 (코드 중복 줄이기용)"""
    def _node(state: AnalyzerState):
        review = state.get("review") or ""
        aspect = state.get("aspect") or []
        label = state.get("label") or []

        sys_msg = f'''
너는 {persona}({role_name})야.
입력된 [aspect], [label] 데이터와 [review] 원문을 분석하여,
네가 담당하는 속성 중 불만족(0)으로 평가된 항목에 대한
구체적인 원인 분석과 맞춤형 해결 방안을 제시해.

[담당 속성 영역]
{target_attrs}

[출력 형식]
[개선 대상 속성]: 불만족 속성들을 쉼표로 구분

- 속성: 속성 이름
- 원인 분석: 리뷰 원문 기반 구체적인 이유
- 개선 방안: {area} 관점의 실질적 해결 방안
'''
        user_msg = f'''
[review]
{review}
[aspect]
{aspect}
[label]
{label}
'''
        response = llm.invoke([
            SystemMessage(content=sys_msg),
            HumanMessage(content=user_msg)
        ])
        return {
            "messages": [response],
            "result_list": [response.content]
        }
    return _node


performance_node = _build_expert_node(
    performance_llm, "performance_llm", "연구원",
    "보습, 커버력, 발색, 자외선 차단, 톤업, 진정, 세정력, 손상케어, 주름개선, 클렌징, 효과, 피부결, 피부, 품질, 성분, 소독효과",
    "제품의 '효능, 성분, 품질' 개선을 담당하는 제품 개발 전문가"
)
price_node = _build_expert_node(
    price_llm, "price_llm", "마케팅",
    "가격, 할인, 가성비, 구성",
    "제품의 '가격 경쟁력 및 경제적 가치' 개선을 담당하는 가격 전략 전문가"
)
texture_node = _build_expert_node(
    Texture_llm, "Texture_llm", "제형 연구원",
    "발림성, 흡수력, 사용감, 제형 밀도, 제형, 유분감, 밀착력, 번짐, 자극, 향",
    "제품의 '제형, 사용감, 피부 자극 및 향기' 개선을 담당하는 제형 개발 전문가"
)
design_node = _build_expert_node(
    Design_llm, "Design_llm", "디자이너",
    "디자인, 색감, 색상, 사이즈, 크기, 휴대성, 편의성, 위생, 포장",
    "제품의 '디자인 및 패키징' 개선을 담당하는 제품 디자인 전문가"
)
service_node = _build_expert_node(
    Service_llm, "Service_llm", "CS",
    "배송, 만족도, 재구매, 피부타입, 사은품",
    "제품의 '배송 서비스 및 고객 경험 관리'를 담당하는 CS 전략 전문가"
)


def route_to_experts(state: AnalyzerState):
    sends = []
    next_nodes = state.get("next_node") or []
    payload = {
        "review": state.get("review"),
        "aspect": state.get("aspect"),
        "label": state.get("label")
    }
    for node_name in next_nodes:
        if node_name in ["performance_node", "price_node", "texture_node", "design_node", "service_node"]:
            sends.append(Send(node_name, payload))
        else:
            sends.append(Send("service_node", payload))
    if not sends:
        sends.append(Send("service_node", payload))
    return sends


def aggregator_node(state: AnalyzerState):
    results = state.get("result_list") or []
    if not results:
        final_answer = "분석 결과가 없습니다."
    else:
        combined_results = "\n\n".join(results)
        final_answer = f"""[종합 제품 개선 제안서]

고객님의 리뷰를 바탕으로 각 분야 전문가들이 분석한 개선 방안입니다.

{combined_results}

---
위 개선 방안이 제품 품질 향상에 도움이 되기를 바랍니다.
"""
    return {"final_result": final_answer}


fb_builder = StateGraph(AnalyzerState)
fb_builder.add_node("router_node", router_node)
fb_builder.add_node("performance_node", performance_node)
fb_builder.add_node("price_node", price_node)
fb_builder.add_node("texture_node", texture_node)
fb_builder.add_node("design_node", design_node)
fb_builder.add_node("service_node", service_node)
fb_builder.add_node("aggregator_node", aggregator_node)

fb_builder.add_edge(START, "router_node")
fb_builder.add_conditional_edges("router_node", route_to_experts,
    ["performance_node", "price_node", "texture_node", "design_node", "service_node"],
)
fb_builder.add_edge("performance_node", "aggregator_node")
fb_builder.add_edge("price_node", "aggregator_node")
fb_builder.add_edge("texture_node", "aggregator_node")
fb_builder.add_edge("design_node", "aggregator_node")
fb_builder.add_edge("service_node", "aggregator_node")
fb_builder.add_edge("aggregator_node", END)

feedback_app = fb_builder.compile()


# ==================================================
# 2. DB 함수 준비
# ==================================================
def init_db():
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS new_user_reviews (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        review TEXT,
        aspect TEXT,
        label TEXT,
        score INTEGER
    )
    """)
    conn.commit()
    conn.close()


def insert_data_db(state: ReviewState):
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    result = state.get("result")
    cursor.execute(
        "INSERT INTO new_user_reviews (review, aspect, label, score) VALUES (?, ?, ?, ?)",
        (
            result["review"].strip(),
            json.dumps(result["aspect"], ensure_ascii=False),
            json.dumps(result["label"]),
            result["score"]
        )
    )
    conn.commit()
    conn.close()


def load_all_reviews() -> pd.DataFrame:
    conn = sqlite3.connect(DB_PATH)
    df = pd.read_sql_query("SELECT * FROM new_user_reviews ORDER BY id ASC", conn)
    conn.close()
    if df.empty:
        return df
    df["aspect_parsed"] = df["aspect"].apply(lambda x: json.loads(x) if x else [])
    df["label_parsed"] = df["label"].apply(lambda x: json.loads(x) if x else [])
    return df


def build_aspect_summary(df: pd.DataFrame, aspect_list) -> pd.DataFrame:
    rows = []
    for aspect in aspect_list:
        pos = neg = 0
        for _, r in df.iterrows():
            aspects = r["aspect_parsed"]
            labels = r["label_parsed"]
            if not aspects or not labels or len(aspects) != len(labels):
                continue
            if aspect in aspects:
                idx = aspects.index(aspect)
                if labels[idx] == 1:
                    pos += 1
                elif labels[idx] == 0:
                    neg += 1
        total = pos + neg
        ratio = (pos / total * 100) if total > 0 else 0.0
        rows.append({
            "aspect": aspect,
            "긍정": pos,
            "부정": neg,
            "언급횟수": total,
            "긍정비율(%)": round(ratio, 1),
        })
    return pd.DataFrame(rows)


# ==================================================
# 3. Streamlit UI
# ==================================================
init_db()

st.title("📊 상품 리뷰 분석 Agent 대시보드")

# --------------------------------------------------
# (상단) 리뷰 입력 / 분석 실행
# --------------------------------------------------
col1, col2 = st.columns(2)

with col1:
    st.subheader("✏️ 리뷰 입력")
    review = st.text_area("리뷰 내용", placeholder="여기에 리뷰를 입력하세요. (20자 이상)")

    current_len = len(review.strip())
    if current_len < 20:
        st.caption(f"📝 현재 {current_len}자 / 최소 20자 필요")
    else:
        st.caption(f"✅ 현재 {current_len}자")

    score = st.radio("별점", [1, 2, 3, 4, 5], horizontal=True)
    run_btn = st.button("분석 실행", type="primary")

with col2:
    st.subheader("🤖 Agent 분석 결과")
    if run_btn:
        review_stripped = review.strip()
        review_len = len(review_stripped)

        if not review_stripped:
            st.warning("리뷰 내용을 입력해주세요.")
        elif review_len < 20:
            st.warning(
                f"⚠️ 리뷰는 20자 이상 작성해주세요. (현재 {review_len}자)"
            )
            st.caption(
                "정확한 분석을 위해서는 충분한 내용이 필요합니다.\n\n"
                "예: '보습력이 정말 좋고 향도 은은해서 마음에 들어요. 가격도 합리적이네요.'"
            )
        else:
            with st.spinner("Agent가 리뷰를 분석하고 있습니다..."):
                initial_state = {
                    "input_review": review,
                    "score": score,
                    "aspect_list": ASPECT_LIST,
                    "max_num": 3,
                    "current_num": 0,
                    "messages": []
                }
                final_state = agent_app.invoke(initial_state)
                insert_data_db(final_state)

            st.success("분석 및 저장이 완료되었습니다!")

            result = final_state.get("result", {})
            aspects = result.get("aspect", []) or []
            labels = result.get("label", []) or []
            final_score = result.get("score", score)

            st.write(f"**리뷰:** {result.get('review', 'N/A')}")
            st.write(f"**별점:** {final_score}")

            if aspects and labels and len(aspects) == len(labels):
                st.markdown("**🏷️ 속성별 평가**")
                detail_df = pd.DataFrame({
                    "속성": aspects,
                    "감성": ["😊 긍정" if l == 1 else "😞 부정" for l in labels],
                })
                st.table(detail_df)
            else:
                st.warning("⚠️ 리뷰에서 분석 대상 속성이 추출되지 않았습니다.")
                st.caption(
                    f"분석 가능한 속성: {', '.join(ASPECT_LIST)}\n\n"
                    "좀 더 구체적인 표현(예: '보습력이 좋아요', '향이 별로예요')을 포함해주세요."
                )

            # ============================================
            # ★ NEW ★ 별점 1~2점이면 피드백 Agent 실행
            # ============================================
            if final_score in [1, 2] and aspects and labels:
                st.divider()
                st.markdown("### 💡 저평가 리뷰 개선 제안")
                st.caption(
                    f"⭐ 별점이 {final_score}점이라 전문가 Agent들이 "
                    "개선 방안을 도출 중입니다..."
                )

                with st.spinner("🔍 분야별 전문가 Agent가 개선안을 작성 중입니다..."):
                    fb_initial_state = {
                        "review": result.get("review", review),
                        "aspect": aspects,
                        "label": labels,
                        "next_node": [],
                        "result_list": [],
                        "final_result": "",
                        "messages": []
                    }
                    fb_final_state = feedback_app.invoke(fb_initial_state)

                # 라우팅된 전문가들 표시
                routed = fb_final_state.get("next_node", [])
                if routed:
                    st.markdown(
                        f"**👥 투입된 전문가:** {', '.join(routed)}"
                    )

                # 각 전문가 의견을 expander로 표시
                expert_results = fb_final_state.get("result_list", [])
                if expert_results:
                    for i, opinion in enumerate(expert_results, 1):
                        with st.expander(f"📝 전문가 의견 #{i}", expanded=(i == 1)):
                            st.markdown(opinion)

                # 종합 제안서
                final_report = fb_final_state.get("final_result", "")
                if final_report:
                    with st.expander("📋 종합 개선 제안서", expanded=True):
                        st.markdown(final_report)
            elif final_score in [1, 2]:
                st.divider()
                st.info(
                    "⭐ 별점이 낮지만, 분석된 속성이 없어 "
                    "개선 제안을 생성하지 못했습니다."
                )
    else:
        st.info("리뷰를 입력하고 '분석 실행'을 눌러주세요.")

st.divider()

# --------------------------------------------------
# DB 로드 (이후 프레임1/프레임2에서 공유)
# --------------------------------------------------
df = load_all_reviews()

if df.empty:
    st.info("아직 분석된 리뷰가 없습니다. 위에서 리뷰를 분석해주세요.")
    st.stop()

# --------------------------------------------------
# 사이드바 필터 (프레임1/프레임2 공통)
# --------------------------------------------------
st.sidebar.header("🔍 필터")
score_min, score_max = st.sidebar.slider("별점 범위", 1, 5, (1, 5))
selected_aspects = st.sidebar.multiselect("포함할 속성", ASPECT_LIST, default=ASPECT_LIST)
keyword = st.sidebar.text_input("리뷰 키워드 검색", "")

mask = df["score"].between(score_min, score_max)
if selected_aspects:
    mask &= df["aspect_parsed"].apply(
        lambda lst: any(a in lst for a in selected_aspects) if lst else False
    )
if keyword:
    mask &= df["review"].fillna("").str.contains(keyword, case=False)

df_f = df[mask].reset_index(drop=True)

# --------------------------------------------------
# 상단 KPI
# --------------------------------------------------
summary_df = build_aspect_summary(df_f, ASPECT_LIST)
total_reviews = len(df_f)
avg_score = round(df_f["score"].mean(), 2) if total_reviews > 0 else 0

k1, k2, k3, k4 = st.columns(4)
k1.metric("총 리뷰 수", f"{total_reviews:,}")
k2.metric("평균 별점", f"{avg_score} / 5")
if not summary_df.empty and summary_df["언급횟수"].sum() > 0:
    best = summary_df.sort_values("긍정비율(%)", ascending=False).iloc[0]
    worst = summary_df.sort_values("긍정비율(%)", ascending=True).iloc[0]
    k3.metric("👍 최고 평가 속성", best["aspect"], f"{best['긍정비율(%)']}%")
    k4.metric("👎 최저 평가 속성", worst["aspect"], f"{worst['긍정비율(%)']}%")

st.divider()

# ==================================================
# 프레임1 : 리뷰 분석 결과 시각화
# ==================================================
st.header("📈 리뷰 분석 결과 시각화")

tab1, tab2, tab3 = st.tabs(["속성별 긍/부정", "별점 분포", "속성별 긍정비율"])

with tab1:
    if summary_df["언급횟수"].sum() == 0:
        st.info("표시할 데이터가 없습니다.")
    else:
        fig, ax = plt.subplots(figsize=(8, 4))
        x = np.arange(len(summary_df))
        ax.bar(x - 0.2, summary_df["긍정"], width=0.4, label="긍정", color="#4C9AFF")
        ax.bar(x + 0.2, summary_df["부정"], width=0.4, label="부정", color="#FF6B6B")
        ax.set_xticks(x)
        ax.set_xticklabels(summary_df["aspect"])
        ax.set_ylabel("건수")
        ax.set_title("속성별 긍정/부정 건수")
        ax.legend()
        st.pyplot(fig)
        st.dataframe(summary_df, use_container_width=True)

with tab2:
    fig, ax = plt.subplots(figsize=(8, 4))
    sns.countplot(data=df_f, x="score", order=[1, 2, 3, 4, 5], ax=ax, color="#4C9AFF")
    ax.set_xlabel("별점")
    ax.set_ylabel("건수")
    ax.set_title("별점 분포")
    st.pyplot(fig)

with tab3:
    if summary_df["언급횟수"].sum() == 0:
        st.info("표시할 데이터가 없습니다.")
    else:
        fig, ax = plt.subplots(figsize=(8, 4))
        ax.barh(summary_df["aspect"], summary_df["긍정비율(%)"], color="#36B37E")
        ax.set_xlim(0, 100)
        ax.set_xlabel("긍정 비율 (%)")
        ax.set_title("속성별 긍정 비율")
        for i, v in enumerate(summary_df["긍정비율(%)"]):
            ax.text(v + 1, i, f"{v}%", va="center")
        st.pyplot(fig)

st.divider()

# ==================================================
# 프레임2 : 리뷰 분석 결과 건별 조회 (+ ★ NEW ★ 피드백 버튼)
# ==================================================
st.header("🔎 리뷰 분석 결과 건별 조회")

# 전체 목록 (보기 좋게 컬럼 정리)
show_df = df_f[["id", "review", "aspect_parsed", "label_parsed", "score"]].copy()
show_df = show_df.rename(columns={"aspect_parsed": "aspect", "label_parsed": "label"})
st.dataframe(show_df, use_container_width=True, height=300)

# 단건 상세
st.subheader("📌 상세 조회")
selected_id = st.selectbox("리뷰 ID 선택", df_f["id"].tolist())
row = df_f[df_f["id"] == selected_id].iloc[0]

c_a, c_b = st.columns([2, 1])
with c_a:
    st.markdown(f"**📝 리뷰 원문**\n\n> {row['review']}")
    st.markdown(f"**⭐ 별점:** {row['score']}")

with c_b:
    st.markdown("**🏷️ 속성별 평가**")
    aspects = row["aspect_parsed"] or []
    labels = row["label_parsed"] or []
    if aspects and labels and len(aspects) == len(labels):
        detail_df = pd.DataFrame({
            "속성": aspects,
            "감성": ["😊 긍정" if l == 1 else "😞 부정" for l in labels],
        })
        st.table(detail_df)
    else:
        st.info("속성 분석 결과가 없습니다.")

# ★ NEW ★ 저평가 리뷰에 대한 사후 피드백 생성 버튼
if row["score"] in [1, 2] and aspects and labels:
    st.divider()
    st.markdown("### 💡 이 리뷰에 대한 개선 제안 생성")
    st.caption(f"⭐ {row['score']}점 리뷰입니다. 전문가 Agent들의 개선안을 받아볼 수 있습니다.")

    if st.button("🚀 개선 제안 생성하기", key=f"gen_feedback_{selected_id}"):
        with st.spinner("🔍 분야별 전문가 Agent가 개선안을 작성 중입니다..."):
            fb_initial_state = {
                "review": row["review"],
                "aspect": aspects,
                "label": labels,
                "next_node": [],
                "result_list": [],
                "final_result": "",
                "messages": []
            }
            fb_final_state = feedback_app.invoke(fb_initial_state)

        routed = fb_final_state.get("next_node", [])
        if routed:
            st.markdown(f"**👥 투입된 전문가:** {', '.join(routed)}")

        expert_results = fb_final_state.get("result_list", [])
        for i, opinion in enumerate(expert_results, 1):
            with st.expander(f"📝 전문가 의견 #{i}", expanded=(i == 1)):
                st.markdown(opinion)

        final_report = fb_final_state.get("final_result", "")
        if final_report:
            with st.expander("📋 종합 개선 제안서", expanded=True):
                st.markdown(final_report)
# Out:
# Overwriting app.py

# %% [markdown]
# * Cloudflare tunnel로 외부 링크 생성

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
# Out:
# (Reading database ... 118256 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2026.3.0) over (2026.3.0) ...
# Setting up cloudflared (2026.3.0) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# * Streamlit (재)시작 (localhost로 붙이기)

# %%
# !pkill -9 -f streamlit || true
# !pkill -9 -f cloudflared || true
# !rm -f streamlit.log cloudflared.log

# !streamlit run app.py \
  --server.port 8501 \
  --server.address 127.0.0.1 \
  --server.headless true \
  --server.enableCORS false \
  --server.enableXsrfProtection false \
  > streamlit.log 2>&1 &
# Out:
# ^C
# ^C

# %% [markdown]
# * 외부 URL 생성 및 접속

# %%
# !cloudflared tunnel --url http://127.0.0.1:8501
# Out:
# 2026-05-13T07:58:46Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-05-13T07:58:46Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-05-13T07:58:50Z INF +--------------------------------------------------------------------------------------------+
# 2026-05-13T07:58:50Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-05-13T07:58:50Z INF |  https://guns-bold-observations-vice.trycloudflare.com                                     |
# 2026-05-13T07:58:50Z INF +--------------------------------------------------------------------------------------------+
# 2026-05-13T07:58:50Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-05-13T07:58:50Z INF Version 2026.3.0 (Checksum 4a9e50e6d6d798e90fcd01933151a90bf7edd99a0a55c28ad18f2e16263a5c30)
# 2026-05-13T07:58:50Z INF GOOS: linux, GOVersion: go1.24.13, GoArch: amd64
# 2026-05-13T07:58:50Z INF Settings: map[ha-connections:1 protocol:quic url:http://127.0.0.1:8501]
# 2026-05-13T07:58:50Z INF cloudflared will not automatically update if installed by a package manager.
# 2026-05-13T07:58:50Z INF Generated Connector ID: 75ecb8e4-0e10-4223-b71f-31b2f01acd5d
# 2026-05-13T07:58:50Z INF Initial protocol quic
# 2026-05-13T07:58:50Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-05-13T07:58:50Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-05-13T07:58:50Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-05-13T07:58:50Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-05-13T07:58:50Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-05-13T07:58:50Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.200.193
# 2026/05/13 07:58:50 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-05-13T07:58:50Z INF Registered tunnel connection connIndex=0 connection=20b66479-0778-4aa2-8c11-d10bbcdcbf47 event=0 ip=198.41.200.193 location=lax01 protocol=quic
# 2026-05-13T07:58:58Z ERR  error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 event=1 ingressRule=0 originService=http://127.0.0.1:8501
# 2026-05-13T07:58:58Z ERR Request failed error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 dest=https://guns-bold-observations-vice.trycloudflare.com/ event=0 ip=198.41.200.193 type=http
# 2026-05-13T07:58:59Z ERR  error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 event=1 ingressRule=0 originService=http://127.0.0.1:8501
# 2026-05-13T07:58:59Z ERR Request failed error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 dest=https://guns-bold-observations-vice.trycloudflare.com/favicon.ico event=0 ip=198.41.200.193 type=http
# 2026-05-13T07:59:22Z ERR  error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 event=1 ingressRule=0 originService=http://127.0.0.1:8501
# 2026-05-13T07:59:22Z ERR Request failed error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 dest=https://guns-bold-observations-vice.trycloudflare.com/ event=0 ip=198.41.200.193 type=http
# 2026-05-13T07:59:22Z ERR  error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 event=1 ingressRule=0 originService=http://127.0.0.1:8501
# 2026-05-13T07:59:22Z ERR Request failed error="Unable to reach the origin service. The service may be down or it may not be responding to traffic from cloudflared: dial tcp 127.0.0.1:8501: connect: connection refused" connIndex=0 dest=https://guns-bold-observations-vice.trycloudflare.com/favicon.ico event=0 ip=198.41.200.193 type=http
